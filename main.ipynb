# %% [markdown]
# # **BASE DE DADOS**

# %% [markdown]
# - Instalação e Importações
#
#   Execute esta células abaixo primeiro para garantir que as bibliotecas estejam presentes.

# %%
import heapq
import networkx as nx
import wikipedia

# %%
# Configurando para a Wikipédia em Português (essencial para seus seeds)
wikipedia.set_lang("pt")

# %% [markdown]
# - Configuração dos Seeds e Stopwords
#
#   Aqui definimos os 5 temas e as palavras de parada para evitar páginas administrativas (como ISBN, Categorias, etc.).

# %%
# Definição dos SEEDS (Pontos de partida)
SEEDS = [
    "Aprendizado de máquina", 
    "The Beatles",
    "Revolução Francesa",
    "One Piece",
    "Rio Grande do Norte"
]

# Lista de Stopwords
STOPS = (
    "International Standard Serial Number",
    "International Standard Book Number",
    "National Diet Library",
    "International Standard Name Identifier",
    "Digital Object Identifier",
    "Arxiv",
    "PubMed",
    "Bibcode",
    "Jstor",
    "Doi (Identificador)",
    "Isbn (Identificador)",
    "Pmid (Identificador)",
    "Arxiv (Identificador)",
    # Adições específicas para limpar a Wikipédia em PT
    "Wikipédia",
    "Ajuda",
    "Ficheiro",
    "Categoria",
    "Portal",
    "Especial",
    "Livro",
    "Predefinição"
)

print(f"Seeds configurados: {SEEDS}")
# Out:
# Seeds configurados: ['Aprendizado de máquina', 'The Beatles', 'Revolução Francesa', 'One Piece', 'Rio Grande do Norte']

# %% [markdown]
# - Construção da Rede
#
#   Este bloco constitui o núcleo da coleta de dados. A implementação clássica do algoritmo de Busca em Largura (Breadth-First Search - BFS) foi adaptada para suportar múltiplos seeds e atingir a profundidade alvo de nível 2 (altura < 3).
#
#   Conforme destacado no Requisito 4, a expansão da rede até este nível acarreta um crescimento exponencial no número de nós e arestas, gerando uma demanda computacional proibitiva para uma busca exaustiva simples. Para viabilizar a coleta e manter o foco nos temas de interesse, substituímos a abordagem padrão por uma estratégia de Busca Gulosa (Greedy Search) com Heurística.
#
# ### Metodologia Aplicada:
#
# 1.  **Estrutura de Dados (Priority Queue):**
#     Substituímos a estrutura de fila convencional (FIFO), típica do BFS, por uma Fila de Prioridade implementada sobre um Min-Heap (heapq). Essa alteração permite que o algoritmo abandone o processamento sequencial cego em favor de uma abordagem ordenada pelo "custo", onde nós de maior relevância (menor score) são processados primeiro.
#
# 2.  **Heurística de Relevância (Score):**
#     Implementamos a função calcular_score_turbo que processa os SEEDS de entrada em tempo de execução, aplicando técnicas simplificadas de PLN (Processamento de Linguagem Natural):
#    * **Extração de Radicais (Stemming):** O algoritmo "limpa" os Seeds e reduz palavras longas aos seus radicais (ex: "Transformer" torna-se "trans"). Isso permite capturar variações (como "Transformação" ou "Transformers"), recuperando o volume de conexões sem perder o contexto.
#     * **Bonificação (-50 pontos):** Se o título da página contiver palavras-chave relacionadas aos 5 SEEDs originais (ex: "Beatles", "Revolução", "Brasil"). Isso mantém a coesão temática da rede.
#     * **Penalidade (+50 pontos):** Se o título for excessivamente longo ou identificado como índices ("Lista de...", "List"), que possuem baixo valor topológico.
#     * **Poda (Pruning) por Página:** Para evitar a explosão combinatória e o ruído, aplicamos um corte rígido (MAX_FILHOS_POR_PAGINA). Após calcular o score de todos os links de uma página, o algoritmo ordena os candidatos e retém apenas os Top N (ex: 20) melhores. Isso garante que apenas a "nata" das conexões seja adicionada ao grafo final.
#
# Dessa forma, garantimos a construção de uma base de dados densa, tematicamente coesa e que respeita os limites computacionais do projeto.

# %%
def gerar_keywords_inteligentes(lista_seeds):
    keywords = set()
    for seed in lista_seeds:
        # 1. Limpa parênteses e converte para minúsculo
        limpo = seed.split("(")[0].lower()
        palavras = limpo.split()
        
        for p in palavras:
            # 2. Aceita palavras a partir de 3 letras (Salva 'Rio', 'One', 'Usa')
            if len(p) >= 3:
                # 3. TRUQUE DO VOLUME: Se a palavra for longa (>5), pega só o radical
                # Ex: "Revolução" vira "revol". "Transformer" vira "trans"
                if len(p) > 5:
                    keywords.add(p[:5]) 
                else:
                    keywords.add(p)
    
    # Remove palavras muito comuns que podem ter passado (ruído)
    palavras_banidas = {"das", "dos", "the", "for", "com", "sem", "sob"}
    keywords = keywords - palavras_banidas
    
    print(f"Keywords Geradas (Raízes): {keywords}")
    return keywords

GLOBAL_KEYWORDS = gerar_keywords_inteligentes(SEEDS)
# Out:
# Keywords Geradas (Raízes): {'franc', 'piece', 'grand', 'beatl', 'máqui', 'one', 'norte', 'revol', 'apren', 'rio'}

# %%
MAX_FILHOS_POR_PAGINA = 20

def calcular_score_turbo(titulo_link, keywords_set):
    """
    Menor é melhor.
    Score Base: 100
    - Contém radical do Seed? -50
    - Título gigante ou Lista? +50
    """
    score = 100
    titulo_lower = titulo_link.lower()

    # Verifica se ALGUMA keyword está contida no título
    # Ex: se keyword é "revol", vai dar match em "Revolução" e "Revolta"
    for k in keywords_set:
        if k in titulo_lower:
            score -= 50
            break 

    # Penalidades
    listas = {"lista", "list", "índice"}
    if len(titulo_link) > 60 or any(l in titulo_lower for l in listas):
        score += 50

    return score

# --- INICIALIZAÇÃO ---
priority_queue = []
for seed in SEEDS:
    heapq.heappush(priority_queue, (0, 0, seed))

todo_set = set(SEEDS)
done_set = set()
g = nx.DiGraph()

print(f"Iniciando Coleta Otimizada (Máx {MAX_FILHOS_POR_PAGINA} filhos/página)...")

# --- LOOP PRINCIPAL ---
while priority_queue:
    layer, score, page = heapq.heappop(priority_queue)

    if layer >= 3: # Profundidade máxima
        continue

    if page in done_set:
        continue

    done_set.add(page)
    print(f"Camada {layer} | Processando: {page} | Grafo: {len(g)} nós")

    try:
        wiki = wikipedia.page(page, auto_suggest=False)
        links_brutos = wiki.links
    except Exception:
        continue

    candidatos = []
    for link in links_brutos:
        link_str = link # wikipedia.links já retorna strings, não precisa .title() as vezes
        if link_str not in STOPS and not link_str.startswith("Lista De"):
            # Passamos o GLOBAL_KEYWORDS gerado lá fora
            s = calcular_score_turbo(link_str, GLOBAL_KEYWORDS)
            candidatos.append((s, link_str))

    # Ordena e Corta
    candidatos.sort(key=lambda x: x[0])
    melhores_filhos = candidatos[:MAX_FILHOS_POR_PAGINA]

    for s, link_escolhido in melhores_filhos:
        g.add_edge(page, link_escolhido)

        if link_escolhido not in todo_set and link_escolhido not in done_set:
            heapq.heappush(priority_queue, (layer + 1, s, link_escolhido))
            todo_set.add(link_escolhido)

print("-" * 30)
print(f"COLETA FINALIZADA!")
print(f"Total: {len(g)} nós e {nx.number_of_edges(g)} arestas.")
# Out:
# Iniciando Coleta Otimizada (Máx 20 filhos/página)...
# Camada 0 | Processando: Aprendizado de máquina | Grafo: 0 nós
# Camada 0 | Processando: One Piece | Grafo: 21 nós
# Camada 0 | Processando: Revolução Francesa | Grafo: 42 nós
# Camada 0 | Processando: Rio Grande do Norte | Grafo: 63 nós
# Camada 0 | Processando: The Beatles | Grafo: 84 nós
# Camada 1 | Processando: 1 (álbum de The Beatles) | Grafo: 105 nós
# Camada 1 | Processando: 18 de brumário | Grafo: 114 nós
# Camada 1 | Processando: 34 Montagu Square, Marylebone | Grafo: 123 nós
# Camada 1 | Processando: A Taste of Honey | Grafo: 123 nós
# Camada 1 | Processando: A Taste of Honey (banda) | Grafo: 139 nós
# Camada 1 | Processando: Acari (Rio Grande do Norte) | Grafo: 157 nós
# Camada 1 | Processando: Alexandria (Rio Grande do Norte) | Grafo: 176 nós
# Camada 1 | Processando: América Futebol Clube (Rio Grande do Norte) | Grafo: 188 nós
# Camada 1 | Processando: América do Norte | Grafo: 204 nós
# Camada 1 | Processando: Análise de componentes principais | Grafo: 223 nós
# Camada 1 | Processando: Aprendizado por transferência | Grafo: 242 nós
# Camada 1 | Processando: Aprendizagem | Grafo: 261 nós
# Camada 1 | Processando: Aprendizagem mecânica | Grafo: 280 nós
# Camada 1 | Processando: Aprendizagem profunda | Grafo: 295 nós
# Camada 1 | Processando: Areia Branca (Rio Grande do Norte) | Grafo: 310 nós
# Camada 1 | Processando: Arez (Rio Grande do Norte) | Grafo: 322 nós
# Camada 1 | Processando: Ariana Grande | Grafo: 333 nós
# Camada 1 | Processando: Arquidiocese de São Sebastião do Rio de Janeiro | Grafo: 351 nós
# Camada 1 | Processando: Assembleia Legislativa do Rio Grande do Norte | Grafo: 371 nós
# Camada 1 | Processando: Assembleia Nacional (Revolução Francesa) | Grafo: 384 nós
# Camada 1 | Processando: Assembleia Nacional Constituinte Francesa | Grafo: 390 nós
# Camada 1 | Processando: Assembleia Nacional Constituinte Francesa (1789) | Grafo: 391 nós
# Camada 1 | Processando: Assembleia Nacional Legislativa (Revolução Francesa) | Grafo: 391 nós
# Camada 1 | Processando: Audição dos Beatles para a Decca Records | Grafo: 394 nós
# Camada 1 | Processando: Bacia do rio São Francisco | Grafo: 394 nós
# Camada 1 | Processando: Banda Negra (Revolução Francesa) | Grafo: 413 nós
# Camada 1 | Processando: Bandeira do Rio Grande do Norte | Grafo: 427 nós
# Camada 1 | Processando: Batalha de Castiglione | Grafo: 445 nós
# Camada 1 | Processando: Beatle boot | Grafo: 460 nós
# Camada 1 | Processando: Beatlemania | Grafo: 460 nós
# Camada 1 | Processando: Beatles Ashram | Grafo: 462 nós
# Camada 1 | Processando: Beatles Bootlegs | Grafo: 462 nós
# Camada 1 | Processando: Beatles for Sale | Grafo: 462 nós
# Camada 1 | Processando: Beatles-Platz | Grafo: 465 nós
# Camada 1 | Processando: Beatlesque | Grafo: 465 nós
# Camada 1 | Processando: Birthday (canção de The Beatles) | Grafo: 465 nós
# Camada 1 | Processando: Blackbird (canção de The Beatles) | Grafo: 483 nós
# Camada 1 | Processando: Blue Period (mangá) | Grafo: 485 nós
# Camada 1 | Processando: Bobby Jones (cantor) | Grafo: 504 nós
# Camada 1 | Processando: Brasão do Rio Grande do Norte | Grafo: 504 nós
# Camada 1 | Processando: Brian Jones | Grafo: 521 nós
# Camada 1 | Processando: Calcário | Grafo: 540 nós
# Camada 1 | Processando: Calderstone Productions | Grafo: 560 nós
# Camada 1 | Processando: Calendário Revolucionário Francês | Grafo: 560 nós
# Camada 1 | Processando: Calendário revolucionário francês | Grafo: 565 nós
# Camada 1 | Processando: Caminhonete | Grafo: 565 nós
# Camada 1 | Processando: Camioneta | Grafo: 583 nós
# Camada 1 | Processando: Campanha francesa no Egito e na Síria | Grafo: 599 nós
# Camada 1 | Processando: Campina Grande | Grafo: 600 nós
# Camada 1 | Processando: Campo aleatório de Markov | Grafo: 618 nós
# Camada 1 | Processando: Capitania do Rio Grande | Grafo: 629 nós
# Camada 1 | Processando: Causas da Revolução Francesa | Grafo: 646 nós
# Camada 1 | Processando: Claude-Henri Belgrand de Vaubois | Grafo: 647 nós
# Camada 1 | Processando: Clero refratário | Grafo: 667 nós
# Camada 1 | Processando: Colaborações entre ex-Beatles | Grafo: 683 nós
# Camada 1 | Processando: Coluna da Grande Armée | Grafo: 683 nós
# Camada 1 | Processando: Comissão dos Doze (Revolução Francesa) | Grafo: 683 nós
# Camada 1 | Processando: Companhia Docas do Rio Grande do Norte | Grafo: 699 nós
# Camada 1 | Processando: Companhia Energética do Rio Grande do Norte | Grafo: 716 nós
# Camada 1 | Processando: Companhia de Águas e Esgotos do Rio Grande do Norte | Grafo: 730 nós
# Camada 1 | Processando: Constituição Francesa de 1791 | Grafo: 732 nós
# Camada 1 | Processando: Constituição Francesa de 1799 (Ano VIII) | Grafo: 740 nós
# Camada 1 | Processando: Constituição Francesa de 1815 | Grafo: 740 nós
# Camada 1 | Processando: Constituição do Estado do Rio Grande do Norte | Grafo: 748 nós
# Camada 1 | Processando: Constituição francesa de 1791 | Grafo: 763 nós
# Camada 1 | Processando: Consulado (Revolução Francesa) | Grafo: 763 nós
# Camada 1 | Processando: Corpo de Bombeiros Militar do Estado do Rio Grande do Norte | Grafo: 763 nós
# Camada 1 | Processando: Dr. Stone | Grafo: 776 nós
# Camada 1 | Processando: Exponencial de Doléans-Dade | Grafo: 790 nós
# Camada 1 | Processando: Grafo aleatório | Grafo: 796 nós
# Camada 1 | Processando: Grand Line | Grafo: 805 nós
# Camada 1 | Processando: Honey & Clover | Grafo: 805 nós
# Camada 1 | Processando: Lei dos grandes números | Grafo: 823 nós
# Camada 1 | Processando: Lobo Solitário | Grafo: 831 nós
# Camada 1 | Processando: Língua japonesa | Grafo: 838 nós
# Camada 1 | Processando: Movimento browniano fracionário | Grafo: 856 nós
# Camada 1 | Processando: Máquina de Vetores de Suporte | Grafo: 861 nós
# Camada 1 | Processando: Máquina de vetores de suporte | Grafo: 874 nós
# Camada 1 | Processando: One Piece (série de televisão) | Grafo: 874 nós
# Camada 1 | Processando: One Piece Film Gold | Grafo: 892 nós
# Camada 1 | Processando: One Piece Film Red | Grafo: 904 nós
# Camada 1 | Processando: One Piece Film Z | Grafo: 913 nós
# Camada 1 | Processando: One Piece Film: Red | Grafo: 918 nós
# Camada 1 | Processando: One Piece Film: Strong World | Grafo: 918 nós
# Camada 1 | Processando: One Piece Film: Z | Grafo: 921 nós
# Camada 1 | Processando: One Piece: Stampede | Grafo: 921 nós
# Camada 1 | Processando: One Punch-Man | Grafo: 924 nós
# Camada 1 | Processando: One-shot | Grafo: 934 nós
# Camada 1 | Processando: Passeio aleatório | Grafo: 952 nós
# Camada 1 | Processando: Passeio aleatório de tempo contínuo | Grafo: 960 nós
# Camada 1 | Processando: Revolução | Grafo: 961 nós
# Camada 1 | Processando: Shonen Jump (magazine) | Grafo: 978 nós
# Camada 1 | Processando: Shonen Jump (revista) | Grafo: 978 nós
# Camada 1 | Processando: Teoria da aprendizagem computacional | Grafo: 978 nós
# Camada 1 | Processando: Timoneiro | Grafo: 996 nós
# Camada 1 | Processando: ARIMA | Grafo: 1009 nós
# Camada 1 | Processando: ARMA | Grafo: 1018 nós
# Camada 1 | Processando: Ablação (inteligência artificial) | Grafo: 1022 nós
# Camada 1 | Processando: Alan Turing | Grafo: 1032 nós
# Camada 1 | Processando: Algoritmo | Grafo: 1051 nós
# Camada 2 | Processando: 101 FM (Campina Grande) | Grafo: 1066 nós
# Camada 2 | Processando: 98 FM (Campina Grande) | Grafo: 1081 nós
# Camada 2 | Processando: A priori e A posteriori | Grafo: 1095 nós
# Camada 2 | Processando: Academia Campinense de Letras (Campina Grande) | Grafo: 1114 nós
# Camada 2 | Processando: Aeroclube de Campina Grande | Grafo: 1114 nós
# Camada 2 | Processando: Aeroportos do Rio de Janeiro S.A. | Grafo: 1130 nós
# Camada 2 | Processando: Afonso Amajones | Grafo: 1132 nós
# Camada 2 | Processando: Aftermath (álbum de The Rolling Stones) | Grafo: 1132 nós
# Camada 2 | Processando: Agência Nacional de Transportes Aquaviários | Grafo: 1137 nós
# Camada 2 | Processando: Agência de Fomento do Rio Grande do Norte | Grafo: 1145 nós
# Camada 2 | Processando: Alagoa Grande | Grafo: 1145 nós
# Camada 2 | Processando: Aleatório | Grafo: 1160 nós
# Camada 2 | Processando: America Football Club (Rio de Janeiro) | Grafo: 1176 nós
# Camada 2 | Processando: América Setentrional | Grafo: 1195 nós
# Camada 2 | Processando: América do Norte Britânica | Grafo: 1195 nós
# Camada 2 | Processando: América francófona | Grafo: 1213 nós
# Camada 2 | Processando: Andrey Nazário Afonso | Grafo: 1226 nós
# Camada 2 | Processando: Aniversário | Grafo: 1234 nós
# Camada 2 | Processando: Antilhas francesas | Grafo: 1252 nós
# Camada 2 | Processando: Aprendizado | Grafo: 1261 nós
# Camada 2 | Processando: Aprendizado de máquina adversário | Grafo: 1261 nós
# Camada 2 | Processando: Aprendizado investigativo | Grafo: 1274 nós
# Camada 2 | Processando: Aprendizado por reforço | Grafo: 1274 nós
# Camada 2 | Processando: Aprendizado por reforço com feedback humano | Grafo: 1289 nós
# Camada 2 | Processando: Aprendizagem (desambiguação) | Grafo: 1292 nós
# Camada 2 | Processando: Aprendizagem adaptativa | Grafo: 1292 nós
# Camada 2 | Processando: Aprendizagem ativa | Grafo: 1302 nós
# Camada 2 | Processando: Aprendizagem baseada em problemas | Grafo: 1302 nós
# Camada 2 | Processando: Aprendizagem de características | Grafo: 1316 nós
# Camada 2 | Processando: Aprendizagem de máquina | Grafo: 1330 nós
# Camada 2 | Processando: Aprendizagem de máquina online | Grafo: 1330 nós
# Camada 2 | Processando: Aprendizagem não supervisionada | Grafo: 1334 nós
# Camada 2 | Processando: Aprendizagem precoce | Grafo: 1334 nós
# Camada 2 | Processando: Aprendizagem significativa | Grafo: 1345 nós
# Camada 2 | Processando: Aprendizagem supervisionada | Grafo: 1355 nós
# Camada 2 | Processando: Ariana Grande: Excuse Me, I Love You | Grafo: 1362 nós
# Camada 2 | Processando: Arquidiocese de Campo Grande | Grafo: 1378 nós
# Camada 2 | Processando: Arquidiocese de São José do Rio Preto | Grafo: 1385 nós
# Camada 2 | Processando: Assembleia Legislativa do Estado do Rio de Janeiro | Grafo: 1392 nós
# Camada 2 | Processando: Assembleia Legislativa do Rio Grande do Sul | Grafo: 1401 nós
# Camada 2 | Processando: Assembleia Nacional Francesa | Grafo: 1416 nós
# Camada 2 | Processando: Automóvel utilitário | Grafo: 1431 nós
# Camada 2 | Processando: Autoritário | Grafo: 1436 nós
# Camada 2 | Processando: Avenida Rio Branco (Natal) | Grafo: 1453 nós
# Camada 2 | Processando: Bacia Sanfranciscana | Grafo: 1460 nós
# Camada 2 | Processando: Bacia do rio Amazonas | Grafo: 1477 nós
# Camada 2 | Processando: Bacia do rio Descoberto | Grafo: 1485 nós
# Camada 2 | Processando: Bacia do rio Doce | Grafo: 1494 nós
# Camada 2 | Processando: Bacia do rio Parnaíba | Grafo: 1505 nós
# Camada 2 | Processando: Bacia do rio Tietê-Jacaré | Grafo: 1509 nós
# Camada 2 | Processando: Bacia do rio da Prata | Grafo: 1517 nós
# Camada 2 | Processando: Banco do Estado do Rio Grande do Norte | Grafo: 1524 nós
# Camada 2 | Processando: Banco do Estado do Rio Grande do Sul | Grafo: 1525 nós
# Camada 2 | Processando: Banco do Estado do Rio de Janeiro (1950-1975) | Grafo: 1531 nós
# Camada 2 | Processando: Banco do Estado do Rio de Janeiro (1975-2004) | Grafo: 1533 nós
# Camada 2 | Processando: Bandeira de Campina Grande | Grafo: 1535 nós
# Camada 2 | Processando: Bandeira do Rio Grande do Sul | Grafo: 1545 nós
# Camada 2 | Processando: Bandeira do estado do Rio de Janeiro | Grafo: 1560 nós
# Camada 2 | Processando: Bang Bang (canção de Jessie J, Ariana Grande e Nicki Minaj) | Grafo: 1568 nós
# Camada 2 | Processando: Baronete | Grafo: 1574 nós
# Camada 2 | Processando: Barão do Rio Branco | Grafo: 1593 nós
# Camada 2 | Processando: Baía de São Francisco | Grafo: 1613 nós
# Camada 2 | Processando: Beatlemania (desambiguação) | Grafo: 1626 nós
# Camada 2 | Processando: Beatles | Grafo: 1626 nós
# Camada 2 | Processando: Beatles 65 | Grafo: 1626 nós
# Camada 2 | Processando: Beatles VI | Grafo: 1626 nós
# Camada 2 | Processando: Blackbird (Beatles) | Grafo: 1645 nós
# Camada 2 | Processando: Bloodline (canção de Ariana Grande) | Grafo: 1645 nós
# Camada 2 | Processando: Blue & Lonesome | Grafo: 1649 nós
# Camada 2 | Processando: Blue Period | Grafo: 1655 nós
# Camada 2 | Processando: Bolsa de Valores do Rio de Janeiro | Grafo: 1655 nós
# Camada 2 | Processando: Boneca | Grafo: 1673 nós
# Camada 2 | Processando: Boneca de pano | Grafo: 1691 nós
# Camada 2 | Processando: Boyfriend (canção de Ariana Grande e Social House) | Grafo: 1703 nós
# Camada 2 | Processando: Brasão de Campina Grande | Grafo: 1706 nós
# Camada 2 | Processando: Brasão do Rio Grande do Sul | Grafo: 1706 nós
# Camada 2 | Processando: Brasão do estado do Rio de Janeiro | Grafo: 1707 nós
# Camada 2 | Processando: Brigada Militar do Rio Grande do Sul | Grafo: 1715 nós
# Camada 2 | Processando: Brook (One Piece) | Grafo: 1726 nós
# Camada 2 | Processando: Brumário | Grafo: 1726 nós
# Camada 2 | Processando: CBN Campina Grande | Grafo: 1738 nós
# Camada 2 | Processando: CEG Rio | Grafo: 1751 nós
# Camada 2 | Processando: Cachoeira (Campina Grande) | Grafo: 1758 nós
# Camada 2 | Processando: Caixa Econômica Estadual do Rio Grande do Sul | Grafo: 1772 nós
# Camada 2 | Processando: Calendário gregoriano | Grafo: 1773 nós
# Camada 2 | Processando: Calendário solar | Grafo: 1793 nós
# Camada 2 | Processando: Camionete | Grafo: 1799 nós
# Camada 2 | Processando: Campina Grande do Sul | Grafo: 1799 nós
# Camada 2 | Processando: Camponeses | Grafo: 1816 nós
# Camada 2 | Processando: Capela Imperial do Rio de Janeiro | Grafo: 1831 nós
# Camada 2 | Processando: Capitania da Ilha Grande de Joanes | Grafo: 1848 nós
# Camada 2 | Processando: Capitania de Nossa Senhora do Rosário de Paranaguá | Grafo: 1853 nós
# Camada 2 | Processando: Capitania de São José do Rio Negro | Grafo: 1855 nós
# Camada 2 | Processando: Capitania de São Pedro do Rio Grande do Sul | Grafo: 1858 nós
# Camada 2 | Processando: Capitania do Cabo Norte | Grafo: 1867 nós
# Camada 2 | Processando: Capitania do Rio Grande de São Pedro | Grafo: 1868 nós
# Camada 2 | Processando: Capitania do Rio de Janeiro | Grafo: 1869 nós
# Camada 2 | Processando: Capitão do donatário | Grafo: 1880 nós
# Camada 2 | Processando: Cartório | Grafo: 1893 nós
# Camada 2 | Processando: Castiglione delle Stiviere | Grafo: 1911 nós
# Camada 2 | Processando: Catedral de São Sebastião do Rio de Janeiro | Grafo: 1928 nós
# Camada 2 | Processando: Centrais de Abastecimento do Rio Grande do Norte | Grafo: 1931 nós
# Camada 2 | Processando: Centro (Campina Grande) | Grafo: 1931 nós
# Camada 2 | Processando: Ciclo Revolucionário | Grafo: 1945 nós
# Camada 2 | Processando: Ciclo revolucionário | Grafo: 1945 nós
# Camada 2 | Processando: Cidades (Campina Grande) | Grafo: 1945 nós
# Camada 2 | Processando: Claystone | Grafo: 1953 nós
# Camada 2 | Processando: Companhia Distribuidora de Gás do Rio de Janeiro | Grafo: 1953 nós
# Camada 2 | Processando: Companhia Estadual de Águas e Esgotos do Rio de Janeiro | Grafo: 1955 nós
# Camada 2 | Processando: Companhia Riograndense de Saneamento | Grafo: 1955 nós
# Camada 2 | Processando: Companhia Riograndense de Telecomunicações | Grafo: 1957 nós
# Camada 2 | Processando: Companhia de Eletricidade do Estado do Rio de Janeiro | Grafo: 1957 nós
# Camada 2 | Processando: Companhia de Engenharia de Tráfego do Rio de Janeiro | Grafo: 1960 nós
# Camada 2 | Processando: Companhia de Navegação do São Francisco | Grafo: 1975 nós
# Camada 2 | Processando: Companhia de Processamento de Dados do Rio Grande do Norte | Grafo: 1977 nós
# Camada 2 | Processando: Companhia de Saneamento do Estado do Rio de Janeiro | Grafo: 1977 nós
# Camada 2 | Processando: Companhia de Telefones do Rio de Janeiro | Grafo: 1977 nós
# Camada 2 | Processando: Comportamento da máquina | Grafo: 1980 nós
# Camada 2 | Processando: Comunismo libertário | Grafo: 1985 nós
# Camada 2 | Processando: Comércio exterior | Grafo: 2005 nós
# Camada 2 | Processando: Cone Sul | Grafo: 2022 nós
# Camada 2 | Processando: Conectividade (teoria dos grafos) | Grafo: 2027 nós
# Camada 2 | Processando: Conectivo lógico | Grafo: 2043 nós
# Camada 2 | Processando: Conel Hugh O'Donel Alexander | Grafo: 2062 nós
# Camada 2 | Processando: Conexionismo | Grafo: 2078 nós
# Camada 2 | Processando: Conjunto Cinza (Campina Grande) | Grafo: 2096 nós
# Camada 2 | Processando: Conselho dos Anciãos (Revolução Francesa) | Grafo: 2096 nós
# Camada 2 | Processando: Consistório | Grafo: 2096 nós
# Camada 2 | Processando: Constituição Francesa de 1793 (Ano I) | Grafo: 2116 nós
# Camada 2 | Processando: Constituição Francesa de 1795 (Ano III) | Grafo: 2118 nós
# Camada 2 | Processando: Constituição Francesa de 1802 (Ano X) | Grafo: 2120 nós
# Camada 2 | Processando: Constituição Francesa de 1804 (Ano XII) | Grafo: 2123 nós
# Camada 2 | Processando: Constituição Francesa de 1814 | Grafo: 2125 nós
# Camada 2 | Processando: Constituição Francesa de 1830 | Grafo: 2131 nós
# Camada 2 | Processando: Constituição Francesa de 1848 | Grafo: 2139 nós
# Camada 2 | Processando: Constituição Francesa de 1852 | Grafo: 2143 nós
# Camada 2 | Processando: Constituição Francesa de 1875 | Grafo: 2147 nós
# Camada 2 | Processando: Constituição do Estado do Rio Grande do Norte de 1935 | Grafo: 2153 nós
# Camada 2 | Processando: Constituição do Estado do Rio Grande do Norte de 1947 | Grafo: 2153 nós
# Camada 2 | Processando: Constituição do Estado do Rio Grande do Norte de 1967 | Grafo: 2153 nós
# Camada 2 | Processando: Constituição do Estado do Rio Grande do Sul | Grafo: 2153 nós
# Camada 2 | Processando: Constituição do Estado do Rio de Janeiro | Grafo: 2163 nós
# Camada 2 | Processando: Consórcio Norte Energia | Grafo: 2176 nós
# Camada 2 | Processando: Contrarrevolucionária | Grafo: 2194 nós
# Camada 2 | Processando: Contrarrevolução | Grafo: 2210 nós
# Camada 2 | Processando: Convenção (Revolução Francesa) | Grafo: 2210 nós
# Camada 2 | Processando: Coronel Azevedo | Grafo: 2211 nós
# Camada 2 | Processando: Corpo de Bombeiros Militar do Estado do Rio de Janeiro | Grafo: 2223 nós
# Camada 2 | Processando: Criminal: France | Grafo: 2233 nós
# Camada 2 | Processando: Criollo | Grafo: 2233 nós
# Camada 2 | Processando: Criptoanálise da Máquina Enigma | Grafo: 2244 nós
# Camada 2 | Processando: Critério de informação de Akaike | Grafo: 2261 nós
# Camada 2 | Processando: Cronologia de The Beatles | Grafo: 2270 nós
# Camada 2 | Processando: Cráton do Norte da China | Grafo: 2285 nós
# Camada 2 | Processando: Culto Decadário | Grafo: 2285 nós
# Camada 2 | Processando: Câmara Municipal do Rio de Janeiro | Grafo: 2296 nós
# Camada 2 | Processando: De revolutionibus orbium coelestium | Grafo: 2305 nós
# Camada 2 | Processando: Debby Boone | Grafo: 2323 nós
# Camada 2 | Processando: Defesa Civil do Rio Grande do Norte | Grafo: 2330 nós
# Camada 2 | Processando: Delta de Kronecker | Grafo: 2330 nós
# Camada 2 | Processando: Depressão Sertaneja-São Francisco | Grafo: 2348 nós
# Camada 2 | Processando: Dialetos japoneses | Grafo: 2363 nós
# Camada 2 | Processando: Dicionário Houaiss | Grafo: 2381 nós
# Camada 2 | Processando: Dificuldade de aprendizagem | Grafo: 2400 nós
# Camada 2 | Processando: Dificuldades de aprendizagem | Grafo: 2407 nós
# Camada 2 | Processando: Dinamérica (Campina Grande) | Grafo: 2407 nós
# Camada 2 | Processando: Diocese de Campina Grande | Grafo: 2407 nós
# Camada 2 | Processando: Diocese de Franca | Grafo: 2410 nós
# Camada 2 | Processando: Diocese de Limoeiro do Norte | Grafo: 2415 nós
# Camada 2 | Processando: Diocese de Osório | Grafo: 2419 nós
# Camada 2 | Processando: Diocese de Palmas e Francisco Beltrão | Grafo: 2423 nós
# Camada 2 | Processando: Diocese de Rio Branco | Grafo: 2428 nós
# Camada 2 | Processando: Diocese de Rio Grande | Grafo: 2436 nós
# Camada 2 | Processando: Diocese de Rio do Sul | Grafo: 2442 nós
# Camada 2 | Processando: Diretório (Revolução Francesa) | Grafo: 2447 nós
# Camada 2 | Processando: Dirty Work (álbum de The Rolling Stones) | Grafo: 2447 nós
# Camada 2 | Processando: Discografia de Ariana Grande | Grafo: 2462 nós
# Camada 2 | Processando: Discografia de The Beatles | Grafo: 2463 nós
# Camada 2 | Processando: Discografia de The Rolling Stones | Grafo: 2470 nós
# Camada 2 | Processando: Distribuição exponencial | Grafo: 2470 nós
# Camada 2 | Processando: Diário Oficial do Estado do Rio Grande do Norte | Grafo: 2480 nós
# Camada 2 | Processando: Diário de Natal | Grafo: 2480 nós
# Camada 2 | Processando: Donatário | Grafo: 2491 nós
# Camada 2 | Processando: Economia de Campina Grande | Grafo: 2498 nós
# Camada 2 | Processando: Eleições estaduais no Rio Grande do Norte em 2022 | Grafo: 2509 nós
# Camada 2 | Processando: Eletrificação Centro-Norte do Ceará | Grafo: 2526 nós
# Camada 2 | Processando: Eletronorte | Grafo: 2526 nós
# Camada 2 | Processando: Emigrações francesas (1789-1815) | Grafo: 2527 nós
# Camada 2 | Processando: Empresa Gestora de Ativos do Rio Grande do Norte | Grafo: 2534 nós
# Camada 2 | Processando: Empresa de Pesquisa Agropecuária do Rio Grande do Norte | Grafo: 2534 nós
# Camada 2 | Processando: Enel Distribuição Rio | Grafo: 2534 nós
# Camada 2 | Processando: Enigma (máquina) | Grafo: 2540 nós
# Camada 2 | Processando: Ensino superior | Grafo: 2552 nós
# Camada 2 | Processando: Ensino-aprendizagem | Grafo: 2569 nós
# Camada 2 | Processando: Equador (Rio Grande do Norte) | Grafo: 2569 nós
# Camada 2 | Processando: Equilíbrio cognitivo | Grafo: 2574 nós
# Camada 2 | Processando: Escrita japonesa | Grafo: 2574 nós
# Camada 2 | Processando: Espírito Santo (Rio Grande do Norte) | Grafo: 2581 nós
# Camada 2 | Processando: Estado do Grão-Pará e Rio Negro | Grafo: 2592 nós
# Camada 2 | Processando: Estado do Rio Grande do Sul | Grafo: 2597 nós
# Camada 2 | Processando: Estados e Revoluções Sociais | Grafo: 2606 nós
# Camada 2 | Processando: Estilos de aprendizagem | Grafo: 2606 nós
# Camada 2 | Processando: Estuário | Grafo: 2613 nós
# Camada 2 | Processando: Estádio Francisco Stédile | Grafo: 2627 nós
# Camada 2 | Processando: Estádio Municipal Coronel José Bezerra | Grafo: 2645 nós
# Camada 2 | Processando: Europa Setentrional | Grafo: 2655 nós
# Camada 2 | Processando: Evento primário | Grafo: 2664 nós
# Camada 2 | Processando: Every Little Thing (canção de The Beatles) | Grafo: 2679 nós
# Camada 2 | Processando: Everyday (canção de Ariana Grande) | Grafo: 2679 nós
# Camada 2 | Processando: Exemplos de Máquinas de Turing | Grafo: 2682 nós
# Camada 2 | Processando: Exile (banda japonesa) | Grafo: 2691 nós
# Camada 2 | Processando: Exército de Terra Francês | Grafo: 2700 nós
# Camada 2 | Processando: Fast & Furious Spy Racers | Grafo: 2715 nós
# Camada 2 | Processando: Federazione Industria Musicale Italiana | Grafo: 2715 nós
# Camada 2 | Processando: Federação Norte-rio-grandense de Futebol | Grafo: 2731 nós
# Camada 2 | Processando: Festa nacional francesa | Grafo: 2741 nós
# Camada 2 | Processando: Filmografia de The Beatles | Grafo: 2755 nós
# Camada 2 | Processando: Flowers (álbum de The Rolling Stones) | Grafo: 2755 nós
# Camada 2 | Processando: Fones (fonética) | Grafo: 2755 nós
# Camada 2 | Processando: For No One | Grafo: 2766 nós
# Camada 2 | Processando: Forças Francesas Livres | Grafo: 2768 nós
# Camada 2 | Processando: Francis Drake | Grafo: 2787 nós
# Camada 2 | Processando: Francis Mansour Zayek | Grafo: 2802 nós
# Camada 2 | Processando: Francisco Barbosa Gomes | Grafo: 2808 nós
# Camada 2 | Processando: Francisco Franco | Grafo: 2822 nós
# Camada 2 | Processando: Francisco I da Áustria | Grafo: 2842 nós
# Camada 2 | Processando: Francisco I. Madero | Grafo: 2860 nós
# Camada 2 | Processando: Francisco Vásquez de Coronado | Grafo: 2876 nós
# Camada 2 | Processando: Francisco da Silveira Dias | Grafo: 2888 nós
# Camada 2 | Processando: Francisco de Sousa | Grafo: 2903 nós
# Camada 2 | Processando: Francisco de São Jerônimo | Grafo: 2920 nós
# Camada 2 | Processando: Francisco do PT | Grafo: 2932 nós
# Camada 2 | Processando: François Hanriot | Grafo: 2944 nós
# Camada 2 | Processando: Frimário | Grafo: 2944 nós
# Camada 2 | Processando: Fuso horário | Grafo: 2948 nós
# Camada 2 | Processando: Futebol do Rio Grande do Norte | Grafo: 2966 nós
# Camada 2 | Processando: Get Back (canção de The Beatles) | Grafo: 2972 nós
# Camada 2 | Processando: Girl (canção de The Beatles) | Grafo: 2973 nós
# Camada 2 | Processando: Global Beatles Day | Grafo: 2973 nós
# Camada 2 | Processando: Glorioso primeiro de junho | Grafo: 2973 nós
# Camada 2 | Processando: Glossário de anime e mangá | Grafo: 2989 nós
# Camada 2 | Processando: Golpe de 18 de Brumário | Grafo: 3002 nós
# Camada 2 | Processando: Governo do Norte (América Portuguesa) | Grafo: 3002 nós
# Camada 2 | Processando: Governo do Rio Grande do Norte | Grafo: 3018 nós
# Camada 2 | Processando: Grafos aleatórios exponenciais | Grafo: 3031 nós
# Camada 2 | Processando: Grand Canyon | Grafo: 3041 nós
# Camada 2 | Processando: Grande Enciclopédia Soviética | Grafo: 3053 nós
# Camada 2 | Processando: Grande Medo | Grafo: 3061 nós
# Camada 2 | Processando: Grande Prémio de Manga | Grafo: 3062 nós
# Camada 2 | Processando: Grande Salto Adiante | Grafo: 3076 nós
# Camada 2 | Processando: Grande-O | Grafo: 3094 nós
# Camada 2 | Processando: Grandes Antilhas | Grafo: 3111 nós
# Camada 2 | Processando: Grandes Lagos da América do Norte | Grafo: 3113 nós
# Camada 2 | Processando: Grandes Planícies | Grafo: 3124 nós
# Camada 2 | Processando: Gritstone | Grafo: 3133 nós
# Camada 2 | Processando: Gronelândia | Grafo: 3133 nós
# Camada 2 | Processando: Guarda Civil do Rio Grande do Sul | Grafo: 3149 nós
# Camada 2 | Processando: Guarda Municipal do Rio de Janeiro | Grafo: 3157 nós
# Camada 2 | Processando: Guarda Policial da Província do Rio de Janeiro | Grafo: 3161 nós
# Camada 2 | Processando: Guerras Revolucionárias Francesas | Grafo: 3168 nós
# Camada 2 | Processando: Guerras revolucionárias francesas | Grafo: 3177 nós
# Camada 2 | Processando: Hemisfério norte | Grafo: 3177 nós
# Camada 2 | Processando: Hemisfério ocidental | Grafo: 3193 nós
# Camada 2 | Processando: Hiansen Vieira Franco | Grafo: 3201 nós
# Camada 2 | Processando: Hidrovia do São Francisco | Grafo: 3214 nós
# Camada 2 | Processando: Hino do Rio Grande do Norte | Grafo: 3222 nós
# Camada 2 | Processando: História da América do Norte | Grafo: 3233 nós
# Camada 2 | Processando: História do Rio Grande do Norte | Grafo: 3249 nós
# Camada 2 | Processando: Homenagens aos Beatles | Grafo: 3249 nós
# Camada 2 | Processando: Honey Don't | Grafo: 3249 nós
# Camada 2 | Processando: Honey Pie | Grafo: 3249 nós
# Camada 2 | Processando: Huge in France | Grafo: 3250 nós
# Camada 2 | Processando: I Honestly Love You | Grafo: 3250 nós
# Camada 2 | Processando: I Need You (canção de The Beatles) | Grafo: 3263 nós
# Camada 2 | Processando: If I Needed Someone | Grafo: 3264 nós
# Camada 2 | Processando: Igreja Imaculado Coração de Maria (Rio de Janeiro) | Grafo: 3264 nós
# Camada 2 | Processando: Igreja de Nossa Senhora da Penha (Rio de Janeiro) | Grafo: 3275 nós
# Camada 2 | Processando: Imagine (canção de Ariana Grande) | Grafo: 3276 nós
# Camada 2 | Processando: Imigração japonesa no Brasil | Grafo: 3278 nós
# Camada 2 | Processando: Impacto cultural de The Beatles | Grafo: 3295 nós
# Camada 2 | Processando: Império Britânico | Grafo: 3300 nós
# Camada 2 | Processando: Império Português | Grafo: 3303 nós
# Camada 2 | Processando: Império do Brasil | Grafo: 3317 nós
# Camada 2 | Processando: In My Head (canção de Ariana Grande) | Grafo: 3329 nós
# Camada 2 | Processando: In the Lonely Hour | Grafo: 3329 nós
# Camada 2 | Processando: Instituto de Pesos e Medidas do Rio Grande do Norte | Grafo: 3343 nós
# Camada 2 | Processando: Instituto de Previdência do Rio Grande do Norte | Grafo: 3343 nós
# Camada 2 | Processando: Inteligência sensório-motora | Grafo: 3343 nós
# Camada 2 | Processando: Interior do Rio Grande do Norte | Grafo: 3343 nós
# Camada 2 | Processando: It's Only Love (canção de The Beatles) | Grafo: 3351 nós
# Camada 2 | Processando: Jacques Alexis Thuriot | Grafo: 3352 nós
# Camada 2 | Processando: Joaquim Silvério de Sousa | Grafo: 3352 nós
# Camada 2 | Processando: José Francisco de Paula Cavalcanti de Albuquerque | Grafo: 3366 nós
# Camada 2 | Processando: João Dias (Rio Grande do Norte) | Grafo: 3384 nós
# Camada 2 | Processando: Julia (Beatles) | Grafo: 3390 nós
# Camada 2 | Processando: Jump Back: The Best of The Rolling Stones | Grafo: 3397 nós
# Camada 2 | Processando: Junta Comercial do Estado do Rio Grande do Norte | Grafo: 3397 nós
# Camada 2 | Processando: Laboratório Nacional Lawrence Berkeley | Grafo: 3397 nós
# Camada 2 | Processando: Laboratório Nacional de Física | Grafo: 3417 nós
# Camada 2 | Processando: Lançamentos brasileiros de The Beatles | Grafo: 3427 nós
# Camada 2 | Processando: Lançamentos norte-americanos de The Beatles | Grafo: 3439 nós
# Camada 2 | Processando: Let Me Love You (canção de Ariana Grande) | Grafo: 3439 nós
# Camada 2 | Processando: Livros japoneses | Grafo: 3441 nós
# Camada 2 | Processando: Língua francesa | Grafo: 3441 nós
# Camada 2 | Processando: Língua japonesa antiga | Grafo: 3457 nós
# Camada 2 | Processando: Língua japonesa antiga tardia | Grafo: 3457 nós
# Camada 2 | Processando: Língua japonesa arcaica | Grafo: 3469 nós
# Camada 2 | Processando: Língua japonesa moderna | Grafo: 3469 nós
# Camada 2 | Processando: Línguas transanfranciscanas | Grafo: 3469 nós
# Camada 2 | Processando: Martins (Rio Grande do Norte) | Grafo: 3486 nós
# Camada 2 | Processando: Master of None | Grafo: 3492 nós
# Camada 2 | Processando: Mesorregião do Vale São-Franciscano da Bahia | Grafo: 3505 nós
# Camada 2 | Processando: Meta-aprendizes | Grafo: 3524 nós
# Camada 2 | Processando: Metamorphosis (álbum de The Rolling Stones) | Grafo: 3524 nós
# Camada 2 | Processando: Microfone | Grafo: 3524 nós
# Camada 2 | Processando: Milestones (álbum de The Rolling Stones) | Grafo: 3541 nós
# Camada 2 | Processando: Ministério da Saúde (Brasil) | Grafo: 3541 nós
# Camada 2 | Processando: Misery (canção de The Beatles) | Grafo: 3560 nós
# Camada 2 | Processando: Modalidade de aprendizagem | Grafo: 3560 nós
# Camada 2 | Processando: Modalidades de aprendizagem | Grafo: 3576 nós
# Camada 2 | Processando: Modelos de suavização exponencial | Grafo: 3576 nós
# Camada 2 | Processando: Moeda honesta | Grafo: 3576 nós
# Camada 2 | Processando: Money (That's What I Want) | Grafo: 3591 nós
# Camada 2 | Processando: Montanha (Revolução Francesa) | Grafo: 3592 nós
# Camada 2 | Processando: Montanheses (Revolução Francesa) | Grafo: 3592 nós
# Camada 2 | Processando: Monte Alegre (Rio Grande do Norte) | Grafo: 3592 nós
# Camada 2 | Processando: Monumento The Beatles | Grafo: 3596 nós
# Camada 2 | Processando: Motoneta | Grafo: 3596 nós
# Camada 2 | Processando: Máquina Enigma | Grafo: 3612 nós
# Camada 2 | Processando: Máquina Moral | Grafo: 3612 nós
# Camada 2 | Processando: Máquina abstrata | Grafo: 3617 nós
# Camada 2 | Processando: Máquina autorreplicadora | Grafo: 3631 nós
# Camada 2 | Processando: Máquina de Turing | Grafo: 3635 nós
# Camada 2 | Processando: Máquina de Turing alternada | Grafo: 3639 nós
# Camada 2 | Processando: Máquina de Turing de Várias Faixas | Grafo: 3647 nós
# Camada 2 | Processando: Máquina de Turing multifita | Grafo: 3647 nós
# Camada 2 | Processando: Máquina de Turing não determinística | Grafo: 3649 nós
# Camada 2 | Processando: Máquina de Turing probabilística | Grafo: 3654 nós
# Camada 2 | Processando: Máquina de Turing quântica | Grafo: 3661 nós
# Camada 2 | Processando: Máquina de Turing somente de leitura | Grafo: 3666 nós
# Camada 2 | Processando: Máquina de Turing somente-leitura de movimentação à direita | Grafo: 3669 nós
# Camada 2 | Processando: Máquina de Turing universal | Grafo: 3673 nós
# Camada 2 | Processando: Máquina de estado líquido | Grafo: 3675 nós
# Camada 2 | Processando: Máquina de estados finitos determinística | Grafo: 3684 nós
# Camada 2 | Processando: Mário Laginha | Grafo: 3700 nós
# Camada 2 | Processando: Mário Spatziani | Grafo: 3714 nós
# Camada 2 | Processando: Natal (Rio Grande do Norte) | Grafo: 3714 nós
# Camada 2 | Processando: No Stone Unturned | Grafo: 3719 nós
# Camada 2 | Processando: Norah Jones | Grafo: 3719 nós
# Camada 2 | Processando: Numerais japoneses | Grafo: 3728 nós
# Camada 2 | Processando: Nísia Floresta (Rio Grande do Norte) | Grafo: 3737 nós
# Camada 2 | Processando: O-Zone | Grafo: 3739 nós
# Camada 2 | Processando: Observatório Europeu do Audiovisual | Grafo: 3748 nós
# Camada 2 | Processando: One (mangaká) | Grafo: 3762 nós
# Camada 2 | Processando: One After 909 | Grafo: 3774 nós
# Camada 2 | Processando: One Direction | Grafo: 3787 nós
# Camada 2 | Processando: One Last Time | Grafo: 3803 nós
# Camada 2 | Processando: One Love Manchester | Grafo: 3803 nós
# Camada 2 | Processando: One-Punch Man | Grafo: 3809 nós
# Camada 2 | Processando: Ouro Branco (Rio Grande do Norte) | Grafo: 3809 nós
# Camada 2 | Processando: PRIO | Grafo: 3813 nós
# Camada 2 | Processando: Palavras japonesas de origem portuguesa | Grafo: 3813 nós
# Camada 2 | Processando: Palmeira Futebol Clube (Rio Grande do Norte) | Grafo: 3820 nós
# Camada 2 | Processando: Parlophone | Grafo: 3827 nós
# Camada 2 | Processando: Parnamirim (Rio Grande do Norte) | Grafo: 3844 nós
# Camada 2 | Processando: Partículas da língua japonesa | Grafo: 3849 nós
# Camada 2 | Processando: Patriotismo | Grafo: 3865 nós
# Camada 2 | Processando: Pilões (Rio Grande do Norte) | Grafo: 3883 nós
# Camada 2 | Processando: Pioneer (empresa) | Grafo: 3888 nós
# Camada 2 | Processando: Poder Judiciário | Grafo: 3905 nós
# Camada 2 | Processando: Poesia japonesa | Grafo: 3912 nós
# Camada 2 | Processando: Polícia Civil do Estado do Rio Grande do Norte | Grafo: 3920 nós
# Camada 2 | Processando: Primeira República Francesa | Grafo: 3920 nós
# Camada 2 | Processando: Primeiro Império Francês | Grafo: 3921 nós
# Camada 2 | Processando: Prontuário Eletrônico | Grafo: 3924 nós
# Camada 2 | Processando: Província de São Pedro do Rio Grande do Sul | Grafo: 3942 nós
# Camada 2 | Processando: Província do Rio Grande do Norte | Grafo: 3942 nós
# Camada 2 | Processando: Província do Rio de Janeiro | Grafo: 3945 nós
# Camada 2 | Processando: Províncias do Império do Brasil | Grafo: 3946 nós
# Camada 2 | Processando: Rain (canção de The Beatles) | Grafo: 3950 nós
# Camada 2 | Processando: Rain on Me (canção de Lady Gaga e Ariana Grande) | Grafo: 3951 nós
# Camada 2 | Processando: Rebelião das máquinas | Grafo: 3956 nós
# Camada 2 | Processando: Refinaria de Petróleo Riograndense | Grafo: 3965 nós
# Camada 2 | Processando: Região Norte do Brasil | Grafo: 3980 nós
# Camada 2 | Processando: Região hidrográfica do São Francisco | Grafo: 3991 nós
# Camada 2 | Processando: Restauração francesa | Grafo: 3995 nós
# Camada 2 | Processando: Revolution 1 | Grafo: 4003 nós
# Camada 2 | Processando: Revolution 9 | Grafo: 4003 nós
# Camada 2 | Processando: Revolução francesa | Grafo: 4003 nós
# Camada 2 | Processando: Rickie Lee Jones | Grafo: 4003 nós
# Camada 2 | Processando: Ridley Jones | Grafo: 4019 nós
# Camada 2 | Processando: Right There (canção de Ariana Grande) | Grafo: 4019 nós
# Camada 2 | Processando: Rio | Grafo: 4019 nós
# Camada 2 | Processando: Rio Abaeté | Grafo: 4026 nós
# Camada 2 | Processando: Rio Apodi | Grafo: 4028 nós
# Camada 2 | Processando: Rio Açu (Rio Grande do Norte) | Grafo: 4034 nós
# Camada 2 | Processando: Rio Grande Energia | Grafo: 4040 nós
# Camada 2 | Processando: Rio Jacu | Grafo: 4044 nós
# Camada 2 | Processando: Rio Jequitaí | Grafo: 4044 nós
# Camada 2 | Processando: Rio Li | Grafo: 4046 nós
# Camada 2 | Processando: Rio Moçoró | Grafo: 4061 nós
# Camada 2 | Processando: Rio Míncio | Grafo: 4061 nós
# Camada 2 | Processando: Rio Paracatu | Grafo: 4074 nós
# Camada 2 | Processando: Rio Piranhas–Açu | Grafo: 4078 nós
# Camada 2 | Processando: Rio Potengi | Grafo: 4078 nós
# Camada 2 | Processando: Rio Potenji | Grafo: 4081 nós
# Camada 2 | Processando: Rio Samburá | Grafo: 4081 nós
# Camada 2 | Processando: Rio São Francisco | Grafo: 4082 nós
# Camada 2 | Processando: Rio Trairi | Grafo: 4090 nós
# Camada 2 | Processando: Rio Urucuia | Grafo: 4103 nós
# Camada 2 | Processando: Rio Verde Grande | Grafo: 4104 nós
# Camada 2 | Processando: Riodacito | Grafo: 4105 nós
# Camada 2 | Processando: Riograndenser Hunsrückisch | Grafo: 4116 nós
# Camada 2 | Processando: Riolito | Grafo: 4132 nós
# Camada 2 | Processando: Rock 'n' Rolling Stones | Grafo: 4132 nós
# Camada 2 | Processando: Rolled Gold: The Very Best of the Rolling Stones | Grafo: 4132 nós
# Camada 2 | Processando: Rolling Stone | Grafo: 4132 nós
# Camada 2 | Processando: Rolling Stones Mobile Studio | Grafo: 4142 nós
# Camada 2 | Processando: Rolling Stones Now! | Grafo: 4161 nós
# Camada 2 | Processando: Rolling Stones Records | Grafo: 4161 nós
# Camada 2 | Processando: Saitama (One Punch-Man) | Grafo: 4167 nós
# Camada 2 | Processando: Santa Cruz (Rio Grande do Norte) | Grafo: 4178 nós
# Camada 2 | Processando: Saxofone | Grafo: 4182 nós
# Camada 2 | Processando: Serra Negra do Norte | Grafo: 4201 nós
# Camada 2 | Processando: Shadow and Bone (série de televisão) | Grafo: 4204 nós
# Camada 2 | Processando: Shimoneta | Grafo: 4220 nós
# Camada 2 | Processando: Silabário | Grafo: 4233 nós
# Camada 2 | Processando: Sistema Universitário de Documentação | Grafo: 4249 nós
# Camada 2 | Processando: Smartphone | Grafo: 4254 nós
# Camada 2 | Processando: Some Girls (álbum de The Rolling Stones) | Grafo: 4257 nós
# Camada 2 | Processando: Stone Age | Grafo: 4258 nós
# Camada 2 | Processando: Stoned | Grafo: 4258 nós
# Camada 2 | Processando: Superior Tribunal de Justiça Desportiva | Grafo: 4267 nós
# Camada 2 | Processando: São Fernando (Rio Grande do Norte) | Grafo: 4277 nós
# Camada 2 | Processando: São Gonçalo Futebol Clube (Rio Grande do Norte) | Grafo: 4282 nós
# Camada 2 | Processando: São Gonçalo do Amarante (Rio Grande do Norte) | Grafo: 4285 nós
# Camada 2 | Processando: São Miguel (Rio Grande do Norte) | Grafo: 4287 nós
# Camada 2 | Processando: São Vicente (Rio Grande do Norte) | Grafo: 4292 nós
# Camada 2 | Processando: Tenente-coronel | Grafo: 4301 nós
# Camada 2 | Processando: Tenório | Grafo: 4318 nós
# Camada 2 | Processando: Teoria da aprendizagem | Grafo: 4323 nós
# Camada 2 | Processando: Teoria do aprendizado estatístico | Grafo: 4327 nós
# Camada 2 | Processando: Teoria do equilíbrio geral | Grafo: 4327 nós
# Camada 2 | Processando: Terciário | Grafo: 4346 nós
# Camada 2 | Processando: Território | Grafo: 4366 nós
# Camada 2 | Processando: Terror (Revolução Francesa) | Grafo: 4382 nós
# Camada 2 | Processando: The Beatles (álbum) | Grafo: 4385 nós
# Camada 2 | Processando: The One (série de televisão) | Grafo: 4385 nós
# Camada 2 | Processando: Tom Jones | Grafo: 4385 nós
# Camada 2 | Processando: Tribuna do Norte | Grafo: 4392 nós
# Camada 2 | Processando: Tribunal de Contas do Estado do Rio Grande do Sul | Grafo: 4400 nós
# Camada 2 | Processando: Tribunal de Contas do Estado do Rio de Janeiro | Grafo: 4407 nós
# Camada 2 | Processando: Tribunal de Contas do Município do Rio de Janeiro | Grafo: 4407 nós
# Camada 2 | Processando: Títulos honoríficos japoneses | Grafo: 4410 nós
# Camada 2 | Processando: Universidade Federal do Rio Grande do Norte | Grafo: 4427 nós
# Camada 2 | Processando: Uta's Songs: One Piece Film Red | Grafo: 4440 nós
# Camada 2 | Processando: Utilitário | Grafo: 4446 nós
# Camada 2 | Processando: Variolito | Grafo: 4459 nós
# Camada 2 | Processando: Vera Cruz (Rio Grande do Norte) | Grafo: 4459 nós
# Camada 2 | Processando: Veículo utilitário esportivo | Grafo: 4464 nós
# Camada 2 | Processando: Wackestone | Grafo: 4477 nós
# Camada 2 | Processando: Warrior Nun | Grafo: 4477 nós
# Camada 2 | Processando: Wild Honey Pie | Grafo: 4477 nós
# Camada 2 | Processando: Xbox One | Grafo: 4477 nós
# Camada 2 | Processando: Águia Imperial Francesa | Grafo: 4495 nós
# Camada 2 | Processando: (Un)well | Grafo: 4509 nós
# Camada 2 | Processando: 03 de setembro | Grafo: 4509 nós
# Camada 2 | Processando: 07-Ghost | Grafo: 4523 nós
# Camada 2 | Processando: 1 de outubro | Grafo: 4539 nós
# Camada 2 | Processando: 1 litre no namida (série de televisão) | Grafo: 4549 nós
# Camada 2 | Processando: 1+2=Paradise | Grafo: 4563 nós
# Camada 2 | Processando: 10 de Março | Grafo: 4577 nós
# Camada 2 | Processando: 10 de maio | Grafo: 4588 nós
# Camada 2 | Processando: 100% Morango | Grafo: 4598 nós
# Camada 2 | Processando: 11 de abril | Grafo: 4612 nós
# Camada 2 | Processando: 11 de dezembro | Grafo: 4624 nós
# Camada 2 | Processando: 13 de Agosto | Grafo: 4633 nós
# Camada 2 | Processando: 14 de abril | Grafo: 4645 nós
# Camada 2 | Processando: 14 de dezembro | Grafo: 4656 nós
# Camada 2 | Processando: 14 de julho | Grafo: 4668 nós
# Camada 2 | Processando: 14 de setembro | Grafo: 4680 nós
# Camada 2 | Processando: 16 de fevereiro | Grafo: 4685 nós
# Camada 2 | Processando: 17 de julho | Grafo: 4693 nós
# Camada 2 | Processando: 1737 | Grafo: 4704 nós
# Camada 2 | Processando: 1748 | Grafo: 4716 nós
# Camada 2 | Processando: 1758 | Grafo: 4720 nós
# Camada 2 | Processando: 1789 | Grafo: 4724 nós
# Camada 2 | Processando: 1791 | Grafo: 4725 nós
# Camada 2 | Processando: 1792 | Grafo: 4727 nós
# Camada 2 | Processando: 1793 | Grafo: 4729 nós
# Camada 2 | Processando: 1795 | Grafo: 4730 nós
# Camada 2 | Processando: 1796 | Grafo: 4732 nós
# Camada 2 | Processando: 18 de Maio | Grafo: 4734 nós
# Camada 2 | Processando: 18 de março | Grafo: 4747 nós
# Camada 2 | Processando: 18 de setembro | Grafo: 4761 nós
# Camada 2 | Processando: 1815 | Grafo: 4774 nós
# Camada 2 | Processando: 1833 | Grafo: 4779 nós
# Camada 2 | Processando: 1839 | Grafo: 4781 nós
# Camada 2 | Processando: 1872 | Grafo: 4784 nós
# Camada 2 | Processando: 1876 | Grafo: 4786 nós
# Camada 2 | Processando: 1892 | Grafo: 4788 nós
# Camada 2 | Processando: 1936 | Grafo: 4789 nós
# Camada 2 | Processando: 1956 | Grafo: 4791 nós
# Camada 2 | Processando: 1957 | Grafo: 4793 nós
# Camada 2 | Processando: 1961 | Grafo: 4794 nós
# Camada 2 | Processando: 1962 | Grafo: 4795 nós
# Camada 2 | Processando: 1968 | Grafo: 4796 nós
# Camada 2 | Processando: 1972 | Grafo: 4797 nós
# Camada 2 | Processando: 1976 | Grafo: 4798 nós
# Camada 2 | Processando: 1978 | Grafo: 4799 nós
# Camada 2 | Processando: 1981 | Grafo: 4800 nós
# Camada 2 | Processando: 1984 | Grafo: 4801 nós
# Camada 2 | Processando: 1989 | Grafo: 4802 nós
# Camada 2 | Processando: 1992 | Grafo: 4804 nós
# Camada 2 | Processando: 1997 | Grafo: 4804 nós
# Camada 2 | Processando: 1998 | Grafo: 4806 nós
# Camada 2 | Processando: 1º de Junho | Grafo: 4808 nós
# Camada 2 | Processando: 2 de Junho | Grafo: 4820 nós
# Camada 2 | Processando: 2000 | Grafo: 4830 nós
# Camada 2 | Processando: 2001 | Grafo: 4831 nós
# Camada 2 | Processando: 2004 | Grafo: 4834 nós
# Camada 2 | Processando: 2005 | Grafo: 4836 nós
# Camada 2 | Processando: 2006 | Grafo: 4837 nós
# Camada 2 | Processando: 2008 | Grafo: 4841 nós
# Camada 2 | Processando: 2009 | Grafo: 4841 nós
# Camada 2 | Processando: 2009 no cinema | Grafo: 4843 nós
# Camada 2 | Processando: 2010 | Grafo: 4862 nós
# Camada 2 | Processando: 2011 | Grafo: 4863 nós
# Camada 2 | Processando: 2012 | Grafo: 4864 nós
# Camada 2 | Processando: 2012 no cinema | Grafo: 4866 nós
# Camada 2 | Processando: 2013 | Grafo: 4884 nós
# Camada 2 | Processando: 2015 | Grafo: 4885 nós
# Camada 2 | Processando: 2016 | Grafo: 4886 nós
# Camada 2 | Processando: 2016 no cinema | Grafo: 4888 nós
# Camada 2 | Processando: 2017 | Grafo: 4902 nós
# Camada 2 | Processando: 2019 | Grafo: 4903 nós
# Camada 2 | Processando: 2019 no cinema | Grafo: 4905 nós
# Camada 2 | Processando: 2020 | Grafo: 4915 nós
# Camada 2 | Processando: 2021 | Grafo: 4917 nós
# Camada 2 | Processando: 2022 no cinema | Grafo: 4920 nós
# Camada 2 | Processando: 2024 | Grafo: 4938 nós
# Camada 2 | Processando: 20th Century Boys | Grafo: 4943 nós
# Camada 2 | Processando: 21 de Maio | Grafo: 4955 nós
# Camada 2 | Processando: 21st Century Boys | Grafo: 4965 nós
# Camada 2 | Processando: 22 de abril | Grafo: 4965 nós
# Camada 2 | Processando: 22 de novembro | Grafo: 4975 nós
# Camada 2 | Processando: 24 de Maio | Grafo: 4984 nós
# Camada 2 | Processando: 25 de Maio | Grafo: 4996 nós
# Camada 2 | Processando: 26 de setembro | Grafo: 5007 nós
# Camada 2 | Processando: 27 de Maio | Grafo: 5015 nós
# Camada 2 | Processando: 28 de Julho | Grafo: 5027 nós
# Camada 2 | Processando: 29 de junho | Grafo: 5037 nós
# Camada 2 | Processando: 3 de agosto | Grafo: 5047 nós
# Camada 2 | Processando: 3 de dezembro | Grafo: 5056 nós
# Camada 2 | Processando: 3 de outubro | Grafo: 5066 nós
# Camada 2 | Processando: 30 de Maio | Grafo: 5077 nós
# Camada 2 | Processando: 31 de Maio | Grafo: 5088 nós
# Camada 2 | Processando: 5 de agosto | Grafo: 5096 nós
# Camada 2 | Processando: 5 de dezembro | Grafo: 5105 nós
# Camada 2 | Processando: 5 de novembro | Grafo: 5116 nós
# Camada 2 | Processando: 50M2 | Grafo: 5127 nós
# Camada 2 | Processando: 6 de Abril | Grafo: 5127 nós
# Camada 2 | Processando: 6 de março | Grafo: 5135 nós
# Camada 2 | Processando: 7 Seeds | Grafo: 5150 nós
# Camada 2 | Processando: 7 de julho | Grafo: 5150 nós
# Camada 2 | Processando: 8 de janeiro | Grafo: 5159 nós
# Camada 2 | Processando: 9 de junho | Grafo: 5167 nós
# Camada 2 | Processando: ARMA (série) | Grafo: 5176 nós
# Camada 2 | Processando: Abade | Grafo: 5195 nós
# Camada 2 | Processando: Abadia | Grafo: 5206 nós
# Camada 2 | Processando: Abadia de Royaumont | Grafo: 5214 nós
# Camada 2 | Processando: Abara | Grafo: 5219 nós
# Camada 2 | Processando: Abbey Road Studios | Grafo: 5226 nós
# Camada 2 | Processando: AbdiWilliams | Grafo: 5239 nós
# Camada 2 | Processando: Ablação | Grafo: 5239 nós
# Camada 2 | Processando: Abstração | Grafo: 5257 nós
# Camada 2 | Processando: Abu Dabi | Grafo: 5271 nós
# Camada 2 | Processando: Acelerador de IA | Grafo: 5284 nós
# Camada 2 | Processando: Acomodação (Piaget) | Grafo: 5286 nós
# Camada 2 | Processando: Aconselhamento psicológico | Grafo: 5299 nós
# Camada 2 | Processando: Act-Age | Grafo: 5299 nós
# Camada 2 | Processando: Ada Lovelace | Grafo: 5299 nós
# Camada 2 | Processando: Adakito | Grafo: 5310 nós
# Camada 2 | Processando: Adamelito | Grafo: 5310 nós
# Camada 2 | Processando: Adele | Grafo: 5311 nós
# Camada 2 | Processando: Adição | Grafo: 5318 nós
# Camada 2 | Processando: Adjetivo | Grafo: 5335 nós
# Camada 2 | Processando: Adjuto Dias De Araujo Neto | Grafo: 5350 nós
# Camada 2 | Processando: Ado (cantora) | Grafo: 5350 nós
# Camada 2 | Processando: AdoroCinema | Grafo: 5354 nós
# Camada 2 | Processando: Adrien-Marie Legendre | Grafo: 5371 nós
# Camada 2 | Processando: Adult contemporary | Grafo: 5381 nós
# Camada 2 | Processando: Aerodinâmica automotiva | Grafo: 5395 nós
# Camada 2 | Processando: Afanito | Grafo: 5412 nós
# Camada 2 | Processando: Afro Samurai | Grafo: 5413 nós
# Camada 2 | Processando: After Life (telessérie) | Grafo: 5422 nós
# Camada 2 | Processando: Age of Samurai: Battle for Japan | Grafo: 5442 nós
# Camada 2 | Processando: Aggretsuko | Grafo: 5442 nós
# Camada 2 | Processando: Agregação por difusão limitada | Grafo: 5457 nós
# Camada 2 | Processando: Agricultura | Grafo: 5464 nós
# Camada 2 | Processando: Aichi Television Broadcasting | Grafo: 5478 nós
# Camada 2 | Processando: Ainori | Grafo: 5484 nós
# Camada 2 | Processando: Ainu (língua) | Grafo: 5484 nós
# Camada 2 | Processando: Air Gear | Grafo: 5495 nós
# Camada 2 | Processando: Aishiteruze Baby | Grafo: 5507 nós
# Camada 2 | Processando: Ajin | Grafo: 5512 nós
# Camada 2 | Processando: Akame ga Kill! | Grafo: 5513 nós
# Camada 2 | Processando: Akemi Okamura | Grafo: 5529 nós
# Camada 2 | Processando: Akimi Yoshida | Grafo: 5529 nós
# Camada 2 | Processando: Al-Khwarizmi | Grafo: 5539 nós
# Camada 2 | Processando: AlRawabi School for Girls | Grafo: 5557 nós
# Camada 2 | Processando: Alan Kay | Grafo: 5568 nós
# Camada 2 | Processando: Albert Soboul | Grafo: 5581 nós
# Camada 2 | Processando: Alberto Maranhão | Grafo: 5590 nós
# Camada 2 | Processando: Aleatoriedade | Grafo: 5598 nós
# Camada 2 | Processando: Aleksandr Khinchin | Grafo: 5598 nós
# Camada 2 | Processando: Alessia Cara | Grafo: 5613 nós
# Camada 2 | Processando: Alexander Ball | Grafo: 5620 nós
# Camada 2 | Processando: Alfredo de Carvalho | Grafo: 5633 nós
# Camada 2 | Processando: Algodão | Grafo: 5647 nós
# Camada 2 | Processando: Algoritmo de Euclides | Grafo: 5662 nós
# Camada 2 | Processando: Algoritmo de busca | Grafo: 5675 nós
# Camada 2 | Processando: Algoritmo de ordenação | Grafo: 5690 nós
# Camada 2 | Processando: Algoritmo ganancioso | Grafo: 5704 nós
# Camada 2 | Processando: Algoritmo genético | Grafo: 5716 nós
# Camada 2 | Processando: Algoritmo probabilístico | Grafo: 5731 nós
# Camada 2 | Processando: Alicia Keys | Grafo: 5743 nós
# Camada 2 | Processando: Alinhamento da inteligência artificial | Grafo: 5748 nós
# Camada 2 | Processando: AllMovie | Grafo: 5754 nós
# Camada 2 | Processando: AllMusic | Grafo: 5763 nós
# Camada 2 | Processando: Allen Newell | Grafo: 5767 nós
# Camada 2 | Processando: AlloCiné | Grafo: 5775 nós
# Camada 2 | Processando: Alonzo Church | Grafo: 5782 nós
# Camada 2 | Processando: Altitude | Grafo: 5792 nós
# Camada 2 | Processando: Alucinação (inteligência artificial) | Grafo: 5810 nós
# Camada 2 | Processando: Aluvião | Grafo: 5817 nós
# Camada 2 | Processando: Alvar | Grafo: 5823 nós
# Camada 2 | Processando: Amarelo | Grafo: 5823 nós
# Camada 2 | Processando: Amazonas | Grafo: 5841 nós
# Camada 2 | Processando: Ambiente social | Grafo: 5846 nós
# Camada 2 | Processando: Ambulância | Grafo: 5848 nós
# Camada 2 | Processando: America (banda) | Grafo: 5866 nós
# Camada 2 | Processando: Amesterdão | Grafo: 5872 nós
# Camada 2 | Processando: Amostra (estatística) | Grafo: 5883 nós
# Camada 2 | Processando: Amostragem (estatística) | Grafo: 5888 nós
# Camada 2 | Processando: Amostragem aleatória simples | Grafo: 5888 nós
# Camada 2 | Processando: Amostragem estratificada | Grafo: 5900 nós
# Camada 2 | Processando: Amostragem por conglomerados | Grafo: 5912 nós
# Camada 2 | Processando: Amostragem sistemática | Grafo: 5912 nós
# Camada 2 | Processando: Amy Winehouse | Grafo: 5912 nós
# Camada 2 | Processando: Anatomia | Grafo: 5916 nós
# Camada 2 | Processando: Andesito | Grafo: 5931 nós
# Camada 2 | Processando: Andrei Kolmogorov | Grafo: 5931 nós
# Camada 2 | Processando: Andrei Markov | Grafo: 5942 nós
# Camada 2 | Processando: Andrei Markov Júnior | Grafo: 5949 nós
# Camada 2 | Processando: Andres Maria de Guzman | Grafo: 5957 nós
# Camada 2 | Processando: Andrew Ng | Grafo: 5957 nós
# Camada 2 | Processando: Anfibolito | Grafo: 5967 nós
# Camada 2 | Processando: Animax | Grafo: 5968 nós
# Camada 2 | Processando: Animação influenciada por animes | Grafo: 5980 nós
# Camada 2 | Processando: Anime | Grafo: 5996 nós
# Camada 2 | Processando: Anime News Network | Grafo: 6000 nós
# Camada 2 | Processando: Anime music video | Grafo: 6008 nós
# Camada 2 | Processando: Animé | Grafo: 6016 nós
# Camada 2 | Processando: Anki | Grafo: 6016 nós
# Camada 2 | Processando: Anortosito | Grafo: 6024 nós
# Camada 2 | Processando: Anti-intelectualismo | Grafo: 6024 nós
# Camada 2 | Processando: Antigo Regime | Grafo: 6034 nós
# Camada 2 | Processando: Antiguidade clássica | Grafo: 6044 nós
# Camada 2 | Processando: Antonio Galves | Grafo: 6057 nós
# Camada 2 | Processando: Antracite | Grafo: 6065 nós
# Camada 2 | Processando: Análise combinatória | Grafo: 6069 nós
# Camada 2 | Processando: Análise de Fourier | Grafo: 6083 nós
# Camada 2 | Processando: Análise de agrupamentos | Grafo: 6090 nós
# Camada 2 | Processando: Análise de algoritmos | Grafo: 6092 nós
# Camada 2 | Processando: Análise de dados | Grafo: 6096 nós
# Camada 2 | Processando: Análise de rede | Grafo: 6109 nós
# Camada 2 | Processando: Análise do comportamento aplicada | Grafo: 6123 nós
# Camada 2 | Processando: Análise exploratória de dados | Grafo: 6135 nós
# Camada 2 | Processando: Análise fatorial | Grafo: 6144 nós
# Camada 2 | Processando: Análise matemática | Grafo: 6145 nós
# Camada 2 | Processando: Apartamento | Grafo: 6152 nós
# Camada 2 | Processando: Apinito | Grafo: 6170 nós
# Camada 2 | Processando: Aplicações da inteligência artifical | Grafo: 6170 nós
# Camada 2 | Processando: Aplito | Grafo: 6184 nós
# Camada 2 | Processando: Apodi | Grafo: 6184 nós
# Camada 2 | Processando: Apple Records | Grafo: 6186 nós
# Camada 2 | Processando: Aproximação | Grafo: 6193 nós
# Camada 2 | Processando: ArXiv | Grafo: 6204 nós
# Camada 2 | Processando: Aragonita | Grafo: 6213 nós
# Camada 2 | Processando: Arco do Triunfo (França) | Grafo: 6231 nós
# Camada 2 | Processando: Arcole | Grafo: 6236 nós
# Camada 2 | Processando: Arcose | Grafo: 6253 nós
# Camada 2 | Processando: Ardósia | Grafo: 6253 nós
# Camada 2 | Processando: Areia | Grafo: 6253 nós
# Camada 2 | Processando: Aresta (teoria dos grafos) | Grafo: 6263 nós
# Camada 2 | Processando: Arg max | Grafo: 6268 nós
# Camada 2 | Processando: Aritmética fundamental | Grafo: 6268 nós
# Camada 2 | Processando: Arrested Development (grupo) | Grafo: 6268 nós
# Camada 2 | Processando: Arte de inteligência artificial | Grafo: 6270 nós
# Camada 2 | Processando: Arthur Samuel | Grafo: 6276 nós
# Camada 2 | Processando: Artigo científico | Grafo: 6280 nós
# Camada 2 | Processando: Asia Motors | Grafo: 6287 nós
# Camada 2 | Processando: Asmik Ace Entertainment | Grafo: 6295 nós
# Camada 2 | Processando: Assembleia dos Notáveis | Grafo: 6295 nós
# Camada 2 | Processando: Association for Computing Machinery | Grafo: 6301 nós
# Camada 2 | Processando: Assortatividade | Grafo: 6311 nós
# Camada 2 | Processando: Augustin Bernard-François Le Goazre de Kervélégan | Grafo: 6313 nós
# Camada 2 | Processando: Austrália | Grafo: 6313 nós
# Camada 2 | Processando: Autocarro | Grafo: 6325 nós
# Camada 2 | Processando: Autocorrelação | Grafo: 6341 nós
# Camada 2 | Processando: Autoencoder | Grafo: 6356 nós
# Camada 2 | Processando: Automorfismo de grafos | Grafo: 6356 nós
# Camada 2 | Processando: Automóvel | Grafo: 6370 nós
# Camada 2 | Processando: Autossimilaridade | Grafo: 6377 nós
# Camada 2 | Processando: Autovalor | Grafo: 6380 nós
# Camada 2 | Processando: Autovalores e autovetores | Grafo: 6394 nós
# Camada 2 | Processando: Autovetor | Grafo: 6394 nós
# Camada 2 | Processando: Avex | Grafo: 6394 nós
# Camada 2 | Processando: Avril Lavigne | Grafo: 6398 nós
# Camada 2 | Processando: Axiomas de probabilidade | Grafo: 6405 nós
# Camada 2 | Processando: Ayaka Miyoshi | Grafo: 6409 nós
# Camada 2 | Processando: Ação (finanças) | Grafo: 6425 nós
# Camada 2 | Processando: BBC | Grafo: 6442 nós
# Camada 2 | Processando: Back in the U.S.S.R. | Grafo: 6457 nós
# Camada 2 | Processando: Bactéria | Grafo: 6457 nós
# Camada 2 | Processando: Bad Reputation | Grafo: 6474 nós
# Camada 2 | Processando: Banda desenhada | Grafo: 6487 nós
# Camada 2 | Processando: Banda musical | Grafo: 6493 nós
# Camada 2 | Processando: Bandeira da Bahia | Grafo: 6508 nós
# Camada 2 | Processando: Bandeira da Paraíba | Grafo: 6512 nós
# Camada 2 | Processando: Bandeira de Alagoas | Grafo: 6517 nós
# Camada 2 | Processando: Bandeira de Goiás | Grafo: 6518 nós
# Camada 2 | Processando: Bandeira de Mato Grosso | Grafo: 6521 nós
# Camada 2 | Processando: Bandeira de Mato Grosso do Sul | Grafo: 6523 nós
# Camada 2 | Processando: Bandeira de Minas Gerais | Grafo: 6523 nós
# Camada 2 | Processando: Bandeira de Pernambuco | Grafo: 6524 nós
# Camada 2 | Processando: Bandeira de Rondônia | Grafo: 6529 nós
# Camada 2 | Processando: Bandeira de Roraima | Grafo: 6531 nós
# Camada 2 | Processando: Bandeira de Santa Catarina | Grafo: 6532 nós
# Camada 2 | Processando: Bara (gênero) | Grafo: 6534 nós

# %% [markdown]
# - Tratamento de Dados (Limpeza)
#   Remoção de duplicatas (ex: plurais) e auto-loops, conforme feito no notebook do professor.

# %%
print(f"Iniciando limpeza em grafo de {len(g)} nós...")
print("Isso pode demorar um pouco devido ao tamanho da rede.")

# 1. Remover auto-loops (Rápido e seguro)
g.remove_edges_from(nx.selfloop_edges(g))

# 2. Fundir plurais (Ex: 'Palavra' e 'Palavras') com verificação
duplicates = [(node, node + "s") for node in g if node + "s" in g]
for u, v in duplicates:
    if u in g and v in g: # <--- PROTEÇÃO: Só funde se ambos ainda existirem
        g = nx.contracted_nodes(g, u, v, self_loops=False)

# 3. Fundir hífens (Ex: 'One-Punch Man' e 'One Punch Man') com verificação
duplicates_hyphen = [(node, node.replace("-", " ")) for node in g
                     if node.replace("-", " ") in g and node != node.replace("-", " ")]

for u, v in duplicates_hyphen:
    if u in g and v in g: # <--- PROTEÇÃO: Só funde se ambos ainda existirem
        g = nx.contracted_nodes(g, u, v, self_loops=False)

# Limpeza técnica de atributos (para evitar erros no Gephi)
for node in g.nodes():
    g.nodes[node].pop('contraction', None)
for u, v in g.edges():
    g.edges[u, v].pop('contraction', None)

print(f"Limpeza concluída! Grafo atual: {len(g)} nós.")
# Out:
# Iniciando limpeza em grafo de 6432 nós...
# Isso pode demorar um pouco devido ao tamanho da rede.
# Limpeza concluída! Grafo atual: 6412 nós.

# %% [markdown]
# - Filtragem e Exportação
#
#   Gera o arquivo final .graphml.

# %%
# Filtra o "Core" da rede: Mantém apenas nós com grau >= 2
# (Nós que têm pelo menos 2 conexões de entrada ou saída)
core = [node for node, deg in dict(g.degree()).items() if deg >= 2]
gsub = g.subgraph(core).copy()

print("-" * 30)
print(f"Grafo Original: {len(g)} nós")
print(f"Grafo Final (Core): {len(gsub)} nós")
print("-" * 30)

# Salva o arquivo para o Gephi

nome_arquivo = "trabalho_final_validacao.graphml"
nx.write_graphml(gsub, nome_arquivo)

print(f"Arquivo '{nome_arquivo}' salvo com sucesso!")
print("Faça o download na aba de arquivos (ícone da pasta) à esquerda.")
# Out:
# ------------------------------
# Grafo Original: 6412 nós
# Grafo Final (Core): 1964 nós
# ------------------------------
# Arquivo 'trabalho_final_validacao.graphml' salvo com sucesso!
# Faça o download na aba de arquivos (ícone da pasta) à esquerda.
