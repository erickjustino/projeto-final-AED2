# %% [markdown]
# # **BASE DE DADOS**

# %% [markdown]
# - Instalação e Importações
#
#   Execute esta células abaixo primeiro para garantir que as bibliotecas estejam presentes.

# %%
import heapq
import networkx as nx
import wikipedia

# %%
# Configurando para a Wikipédia em Português (essencial para seus seeds)
wikipedia.set_lang("pt")

# %% [markdown]
# - Configuração dos Seeds e Stopwords
#
#   Aqui definimos os 5 temas e as palavras de parada para evitar páginas administrativas (como ISBN, Categorias, etc.).

# %%
# Definição dos SEEDS (Pontos de partida)
SEEDS = [
    "Transformer (modelo de aprendizado de máquina)", # Ajustado para o título correto na PT-Wiki
    "The Beatles",
    "Revolução Francesa",
    "One Piece",
    "Rio Grande do Norte"
]

# Lista de Stopwords
STOPS = (
    "International Standard Serial Number",
    "International Standard Book Number",
    "National Diet Library",
    "International Standard Name Identifier",
    "Digital Object Identifier",
    "Arxiv",
    "PubMed",
    "Bibcode",
    "Jstor",
    "Doi (Identificador)",
    "Isbn (Identificador)",
    "Pmid (Identificador)",
    "Arxiv (Identificador)",
    # Adições específicas para limpar a Wikipédia em PT
    "Wikipédia",
    "Ajuda",
    "Ficheiro",
    "Categoria",
    "Portal",
    "Especial",
    "Livro",
    "Predefinição"
)

print(f"Seeds configurados: {SEEDS}")
# Out:
# Seeds configurados: ['Transformer (modelo de aprendizado de máquina)', 'The Beatles', 'Revolução Francesa', 'One Piece', 'Rio Grande do Norte']

# %% [markdown]
# - Construção da Rede
#
#   Este bloco constitui o núcleo da coleta de dados. A implementação clássica do algoritmo de Busca em Largura (Breadth-First Search - BFS) foi adaptada para suportar múltiplos seeds e atingir a profundidade alvo de nível 2 (altura < 3).
#
#   Conforme destacado no Requisito 4, a expansão da rede até este nível acarreta um crescimento exponencial no número de nós e arestas, gerando uma demanda computacional proibitiva para uma busca exaustiva simples. Para viabilizar a coleta e manter o foco nos temas de interesse, substituímos a abordagem padrão por uma estratégia de Busca Gulosa (Greedy Search) com Heurística.
#
# ### Metodologia Aplicada:
#
# 1.  **Estrutura de Dados (Priority Queue):**
#     Substituímos a estrutura de fila convencional (FIFO), típica do BFS, por uma Fila de Prioridade implementada sobre um Min-Heap (heapq). Essa alteração permite que o algoritmo abandone o processamento sequencial cego em favor de uma abordagem ordenada pelo "custo", onde nós de maior relevância (menor score) são processados primeiro.
#
# 2.  **Heurística de Relevância (Score):**
#     Implementamos a função calcular_score_turbo que processa os SEEDS de entrada em tempo de execução, aplicando técnicas simplificadas de PLN (Processamento de Linguagem Natural):
#    * **Extração de Radicais (Stemming):** O algoritmo "limpa" os Seeds e reduz palavras longas aos seus radicais (ex: "Transformer" torna-se "trans"). Isso permite capturar variações (como "Transformação" ou "Transformers"), recuperando o volume de conexões sem perder o contexto.
#     * **Bonificação (-50 pontos):** Se o título da página contiver palavras-chave relacionadas aos 5 SEEDs originais (ex: "Beatles", "Revolução", "Brasil"). Isso mantém a coesão temática da rede.
#     * **Penalidade (+50 pontos):** Se o título for excessivamente longo ou identificado como índices ("Lista de...", "List"), que possuem baixo valor topológico.
#     * **Poda (Pruning) por Página:** Para evitar a explosão combinatória e o ruído, aplicamos um corte rígido (MAX_FILHOS_POR_PAGINA). Após calcular o score de todos os links de uma página, o algoritmo ordena os candidatos e retém apenas os Top N (ex: 20) melhores. Isso garante que apenas a "nata" das conexões seja adicionada ao grafo final.
#
# Dessa forma, garantimos a construção de uma base de dados densa, tematicamente coesa e que respeita os limites computacionais do projeto.

# %%
def gerar_keywords_inteligentes(lista_seeds):
    keywords = set()
    for seed in lista_seeds:
        # 1. Limpa parênteses e converte para minúsculo
        limpo = seed.split("(")[0].lower()
        palavras = limpo.split()
        
        for p in palavras:
            # 2. Aceita palavras a partir de 3 letras (Salva 'Rio', 'One', 'Usa')
            if len(p) >= 3:
                # 3. TRUQUE DO VOLUME: Se a palavra for longa (>5), pega só o radical
                # Ex: "Revolução" vira "revol". "Transformer" vira "trans"
                if len(p) > 5:
                    keywords.add(p[:5]) 
                else:
                    keywords.add(p)
    
    # Remove palavras muito comuns que podem ter passado (ruído)
    palavras_banidas = {"das", "dos", "the", "for", "com", "sem", "sob"}
    keywords = keywords - palavras_banidas
    
    print(f"Keywords Geradas (Raízes): {keywords}")
    return keywords

GLOBAL_KEYWORDS = gerar_keywords_inteligentes(SEEDS)
# Out:
# Keywords Geradas (Raízes): {'franc', 'piece', 'trans', 'grand', 'beatl', 'one', 'norte', 'revol', 'rio'}

# %%
MAX_FILHOS_POR_PAGINA = 20

def calcular_score_turbo(titulo_link, keywords_set):
    """
    Menor é melhor.
    Score Base: 100
    - Contém radical do Seed? -50
    - Título gigante ou Lista? +50
    """
    score = 100
    titulo_lower = titulo_link.lower()

    # Verifica se ALGUMA keyword está contida no título
    # Ex: se keyword é "revol", vai dar match em "Revolução" e "Revolta"
    for k in keywords_set:
        if k in titulo_lower:
            score -= 50
            break 

    # Penalidades
    listas = {"lista", "list", "índice"}
    if len(titulo_link) > 60 or any(l in titulo_lower for l in listas):
        score += 50

    return score

# --- INICIALIZAÇÃO ---
priority_queue = []
for seed in SEEDS:
    heapq.heappush(priority_queue, (0, 0, seed))

todo_set = set(SEEDS)
done_set = set()
g = nx.DiGraph()

print(f"Iniciando Coleta Otimizada (Máx {MAX_FILHOS_POR_PAGINA} filhos/página)...")

# --- LOOP PRINCIPAL ---
while priority_queue:
    layer, score, page = heapq.heappop(priority_queue)

    if layer >= 3: # Profundidade máxima
        continue

    if page in done_set:
        continue

    done_set.add(page)
    print(f"Camada {layer} | Processando: {page} | Grafo: {len(g)} nós")

    try:
        wiki = wikipedia.page(page, auto_suggest=False)
        links_brutos = wiki.links
    except Exception:
        continue

    candidatos = []
    for link in links_brutos:
        link_str = link # wikipedia.links já retorna strings, não precisa .title() as vezes
        if link_str not in STOPS and not link_str.startswith("Lista De"):
            # Passamos o GLOBAL_KEYWORDS gerado lá fora
            s = calcular_score_turbo(link_str, GLOBAL_KEYWORDS)
            candidatos.append((s, link_str))

    # Ordena e Corta
    candidatos.sort(key=lambda x: x[0])
    melhores_filhos = candidatos[:MAX_FILHOS_POR_PAGINA]

    for s, link_escolhido in melhores_filhos:
        g.add_edge(page, link_escolhido)

        if link_escolhido not in todo_set and link_escolhido not in done_set:
            heapq.heappush(priority_queue, (layer + 1, s, link_escolhido))
            todo_set.add(link_escolhido)

print("-" * 30)
print(f"COLETA FINALIZADA!")
print(f"Total: {len(g)} nós e {nx.number_of_edges(g)} arestas.")
# Out:
# Iniciando Coleta Otimizada (Máx 20 filhos/página)...
# Camada 0 | Processando: One Piece | Grafo: 0 nós
# Camada 0 | Processando: Revolução Francesa | Grafo: 21 nós
# Camada 0 | Processando: Rio Grande do Norte | Grafo: 21 nós
# Camada 0 | Processando: The Beatles | Grafo: 42 nós
# Camada 0 | Processando: Transformer (modelo de aprendizado de máquina) | Grafo: 63 nós
# Camada 1 | Processando: ...Baby One More Time | Grafo: 63 nós
# Camada 1 | Processando: 1 (Beatles album) | Grafo: 82 nós
# Camada 1 | Processando: 20 Greatest Hits (Beatles album) | Grafo: 93 nós
# Camada 1 | Processando: 2025 Indonesian protests | Grafo: 110 nós
# Camada 1 | Processando: 34 Montagu Square, Marylebone | Grafo: 130 nós
# Camada 1 | Processando: 4 by the Beatles | Grafo: 143 nós
# Camada 1 | Processando: A Collection of Beatles Oldies | Grafo: 150 nós
# Camada 1 | Processando: A Salute to the Beatles: Once upon a Time | Grafo: 155 nós
# Camada 1 | Processando: A Taste of Honey (band) | Grafo: 166 nós
# Camada 1 | Processando: A Taste of Honey (song) | Grafo: 184 nós
# Camada 1 | Processando: Acari, Rio Grande do Norte | Grafo: 195 nós
# Camada 1 | Processando: Alexandria, Rio Grande do Norte | Grafo: 214 nós
# Camada 1 | Processando: All Together Now (Beatles song) | Grafo: 216 nós
# Camada 1 | Processando: Apodi, Rio Grande do Norte | Grafo: 223 nós
# Camada 1 | Processando: Areia Branca, Rio Grande do Norte | Grafo: 226 nós
# Camada 1 | Processando: Ariana Grande | Grafo: 228 nós
# Camada 1 | Processando: Around the Beatles | Grafo: 246 nós
# Camada 1 | Processando: Arês, Rio Grande do Norte | Grafo: 247 nós
# Camada 1 | Processando: Assu, Rio Grande do Norte | Grafo: 249 nós
# Camada 1 | Processando: Baraúna, Rio Grande do Norte | Grafo: 255 nós
# Camada 1 | Processando: Barcelona, Rio Grande do Norte | Grafo: 257 nós
# Camada 1 | Processando: Beatle boot | Grafo: 262 nós
# Camada 1 | Processando: Beatlemania | Grafo: 264 nós
# Camada 1 | Processando: Beatlemania (musical) | Grafo: 267 nós
# Camada 1 | Processando: Beatles '64 | Grafo: 267 nós
# Camada 1 | Processando: Beatles '65 | Grafo: 269 nós
# Camada 1 | Processando: Beatles (disambiguation) | Grafo: 269 nós
# c:\Users\Alice\AppData\Local\pypoetry\Cache\virtualenvs\analise-redes-wiki-UZXaxLaG-py3.14\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\Alice\AppData\Local\pypoetry\Cache\virtualenvs\analise-redes-wiki-UZXaxLaG-py3.14\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# Camada 1 | Processando: Beatles (novel) | Grafo: 269 nós
# Camada 1 | Processando: Beatles-Platz | Grafo: 288 nós
# Camada 1 | Processando: Bom Jesus, Rio Grande do Norte | Grafo: 288 nós
# Camada 1 | Processando: Brejinho, Rio Grande do Norte | Grafo: 292 nós
# Camada 1 | Processando: Brook (One Piece) | Grafo: 297 nós
# Camada 1 | Processando: Butsu Zone | Grafo: 303 nós
# Camada 1 | Processando: Caiçara do Norte | Grafo: 322 nós
# Camada 1 | Processando: Caiçara do Rio do Vento | Grafo: 325 nós
# Camada 1 | Processando: Campo Grande, Rio Grande do Norte | Grafo: 329 nós
# Camada 1 | Processando: Campo Redondo, Rio Grande do Norte | Grafo: 333 nós
# Camada 1 | Processando: Captaincy of Rio Grande | Grafo: 336 nós
# Camada 1 | Processando: Caraúbas, Rio Grande do Norte | Grafo: 354 nós
# Camada 1 | Processando: Cerro Corá, Rio Grande do Norte | Grafo: 355 nós
# Camada 1 | Processando: Coronel Ezequiel | Grafo: 355 nós
# Camada 1 | Processando: Coronel João Pessoa | Grafo: 358 nós
# Camada 1 | Processando: Encanto, Rio Grande do Norte | Grafo: 362 nós
# Camada 1 | Processando: Euronews | Grafo: 370 nós
# Camada 1 | Processando: Franky (One Piece) | Grafo: 390 nós
# Camada 1 | Processando: From TV Animation - One Piece: Grand Battle! | Grafo: 391 nós
# Camada 1 | Processando: From TV Animation - One Piece: Grand Battle! 2 | Grafo: 397 nós
# Camada 1 | Processando: From TV Animation - One Piece: Set Sail Pirate Crew! | Grafo: 407 nós
# Camada 1 | Processando: Independence Day (Indonesia) | Grafo: 410 nós
# Camada 1 | Processando: Koisuru One Piece | Grafo: 430 nós
# Camada 1 | Processando: Media franchise | Grafo: 432 nós
# Camada 1 | Processando: Music of One Piece | Grafo: 452 nós
# Camada 1 | Processando: Nami (One Piece) | Grafo: 454 nós
# Camada 1 | Processando: One Piece: Baron Omatsuri and the Secret Island | Grafo: 454 nós
# Camada 1 | Processando: One Piece: Become the Pirate King! | Grafo: 454 nós
# Camada 1 | Processando: One Piece: Burning Blood | Grafo: 455 nós
# Camada 1 | Processando: One Piece: Grand Adventure | Grafo: 456 nós
# Camada 1 | Processando: One Piece: Grand Battle! | Grafo: 457 nós
# Camada 1 | Processando: One Piece: Heroines | Grafo: 459 nós
# Camada 1 | Processando: One-shot (comics) | Grafo: 459 nós
# Camada 2 | Processando: ...Baby One More Time (album) | Grafo: 478 nós
# Camada 2 | Processando: ...Baby One More Time Tour | Grafo: 492 nós
# Camada 2 | Processando: ...But Seriously | Grafo: 500 nós
# Camada 2 | Processando: 1 (The Beatles album) | Grafo: 511 nós
# Camada 2 | Processando: 2014 Indonesian presidential election | Grafo: 511 nós
# Camada 2 | Processando: 2019 Indonesian protests and riots | Grafo: 531 nós
# Camada 2 | Processando: 2022 Indonesian student protests | Grafo: 548 nós
# Camada 2 | Processando: 2024 Indonesian local election law protests | Grafo: 558 nós
# Camada 2 | Processando: 2024 Indonesian local elections | Grafo: 564 nós
# Camada 2 | Processando: A Taste of Honey | Grafo: 566 nós
# Camada 2 | Processando: A Taste of Honey (album) | Grafo: 584 nós
# Camada 2 | Processando: A Taste of Honey (disambiguation) | Grafo: 600 nós
# Camada 2 | Processando: A Taste of Honey (film) | Grafo: 600 nós
# Camada 2 | Processando: A-One (TV channel) | Grafo: 619 nós
# Camada 2 | Processando: Abandoned footwear | Grafo: 636 nós
# Camada 2 | Processando: Abortion in Indonesia | Grafo: 654 nós
# Camada 2 | Processando: Advocates for Trans Equality | Grafo: 657 nós
# Camada 2 | Processando: Agriculture in Indonesia | Grafo: 677 nós
# Camada 2 | Processando: Alicia Silverstone | Grafo: 693 nós
# Camada 2 | Processando: All-Indonesian Students' Union | Grafo: 711 nós
# Camada 2 | Processando: Alvida (One Piece) | Grafo: 727 nós
# Camada 2 | Processando: Analog transmission | Grafo: 737 nós
# Camada 2 | Processando: Anarchism in Indonesia | Grafo: 757 nós
# Camada 2 | Processando: Architecture of Indonesia | Grafo: 773 nós
# Camada 2 | Processando: Ariana Grande at the BBC | Grafo: 778 nós
# Camada 2 | Processando: Ariana Grande discography | Grafo: 792 nós
# Camada 2 | Processando: Ariana Grande videography | Grafo: 797 nós
# Camada 2 | Processando: Ariana Grande: Dangerous Woman Diaries | Grafo: 802 nós
# Camada 2 | Processando: Ariana Grande: Excuse Me, I Love You | Grafo: 809 nós
# Camada 2 | Processando: Arion (journal) | Grafo: 811 nós
# Camada 2 | Processando: Armorial of Indonesia | Grafo: 831 nós
# Camada 2 | Processando: Attorney General's Office of Indonesia | Grafo: 832 nós
# Camada 2 | Processando: August 2025 Indonesian protests | Grafo: 845 nós
# Camada 2 | Processando: Automotive industry in Indonesia | Grafo: 851 nós
# Camada 2 | Processando: Aviation in Indonesia | Grafo: 854 nós
# Camada 2 | Processando: BMG-Ariola | Grafo: 872 nós
# Camada 2 | Processando: Baby One More Time (disambiguation) | Grafo: 892 nós
# Camada 2 | Processando: Bad Idea (Ariana Grande song) | Grafo: 892 nós
# Camada 2 | Processando: Bahasa Indonesia | Grafo: 896 nós
# Camada 2 | Processando: Bang Bang (Jessie J, Ariana Grande and Nicki Minaj song) | Grafo: 914 nós
# Camada 2 | Processando: Bank Indonesia | Grafo: 917 nós
# Camada 2 | Processando: Batik in Indonesia | Grafo: 934 nós
# Camada 2 | Processando: Be Alright (Ariana Grande song) | Grafo: 936 nós
# Camada 2 | Processando: Beatles Ashram | Grafo: 936 nós
# Camada 2 | Processando: Beatles Monthly | Grafo: 936 nós
# Camada 2 | Processando: Beatles Stories | Grafo: 947 nós
# Camada 2 | Processando: Beatles VI | Grafo: 948 nós
# Camada 2 | Processando: Beatles for Sale | Grafo: 949 nós
# Camada 2 | Processando: Beatles for Sale (EP) | Grafo: 950 nós
# Camada 2 | Processando: Beatles for Sale No. 2 | Grafo: 951 nós
# Camada 2 | Processando: Beatlesque | Grafo: 951 nós
# Camada 2 | Processando: Bentham (One Piece) | Grafo: 953 nós
# Camada 2 | Processando: Birth of the Beatles | Grafo: 953 nós
# Camada 2 | Processando: Bloodline (Ariana Grande song) | Grafo: 954 nós
# Camada 2 | Processando: Bojonegoro Regency | Grafo: 954 nós
# Camada 2 | Processando: Bone Regency | Grafo: 970 nós
# Camada 2 | Processando: Boney M. | Grafo: 986 nós
# Camada 2 | Processando: Boyfriend (Ariana Grande and Social House song) | Grafo: 1000 nós
# Camada 2 | Processando: Break-up of the Beatles | Grafo: 1001 nós
# Camada 2 | Processando: Britney Spears: In the Zone | Grafo: 1002 nós
# Camada 2 | Processando: Britney: Piece of Me | Grafo: 1011 nós
# Camada 2 | Processando: Brookstone | Grafo: 1019 nós
# Camada 2 | Processando: Buggy (One Piece) | Grafo: 1039 nós
# Camada 2 | Processando: Bye (Ariana Grande song) | Grafo: 1039 nós
# Camada 2 | Processando: CNN Indonesia | Grafo: 1040 nós
# Camada 2 | Processando: Cabinet of Indonesia | Grafo: 1056 nós
# Camada 2 | Processando: Candi of Indonesia | Grafo: 1056 nós
# Camada 2 | Processando: Capital of Indonesia | Grafo: 1058 nós
# Camada 2 | Processando: Capture of the schooner Bravo | Grafo: 1059 nós
# Camada 2 | Processando: Cat Valentine (Victorious) | Grafo: 1072 nós
# Camada 2 | Processando: Censorship in Indonesia | Grafo: 1089 nós
# Camada 2 | Processando: Chaka (One Piece) | Grafo: 1092 nós
# Camada 2 | Processando: Chaloner Ogle | Grafo: 1092 nós
# Camada 2 | Processando: Channel One (Russia) | Grafo: 1095 nós
# Camada 2 | Processando: Channel One Russia | Grafo: 1111 nós
# Camada 2 | Processando: Chess (One Piece) | Grafo: 1111 nós
# Camada 2 | Processando: Chief of the Indonesian National Police | Grafo: 1111 nós
# Camada 2 | Processando: Choo (One Piece) | Grafo: 1113 nós
# Camada 2 | Processando: Cinema of Indonesia | Grafo: 1113 nós
# Camada 2 | Processando: Climate change in Indonesia | Grafo: 1118 nós
# Camada 2 | Processando: Climate of Indonesia | Grafo: 1121 nós
# Camada 2 | Processando: Collaborations between ex-Beatles | Grafo: 1138 nós
# Camada 2 | Processando: Colonel | Grafo: 1140 nós
# Camada 2 | Processando: Colonial architecture of Indonesia | Grafo: 1158 nós
# Camada 2 | Processando: Colour revolution | Grafo: 1158 nós
# Camada 2 | Processando: Commander of the Indonesian National Armed Forces | Grafo: 1177 nós
# Camada 2 | Processando: Communications in Indonesia | Grafo: 1191 nós
# Camada 2 | Processando: Communion of Churches in Indonesia | Grafo: 1193 nós
# Camada 2 | Processando: Conservation in Indonesia | Grafo: 1210 nós
# Camada 2 | Processando: Constitution of Indonesia | Grafo: 1210 nós
# Camada 2 | Processando: Constitutional Court of Indonesia | Grafo: 1210 nós
# Camada 2 | Processando: Criminal Procedure Law of Indonesia | Grafo: 1210 nós
# Camada 2 | Processando: Crocodile (One Piece) | Grafo: 1210 nós
# Camada 2 | Processando: Cultural impact of the Beatles | Grafo: 1210 nós
# Camada 2 | Processando: Curiosity Channel | Grafo: 1220 nós
# Camada 2 | Processando: Curiosity Stream | Grafo: 1237 nós
# Camada 2 | Processando: DCI Indonesia | Grafo: 1237 nós
# Camada 2 | Processando: Davy Jones (Pirates of the Caribbean) | Grafo: 1237 nós
# Camada 2 | Processando: Davy Jones's locker | Grafo: 1239 nós
# Camada 2 | Processando: Debby Boone | Grafo: 1246 nós
# Camada 2 | Processando: Don't Let Me Down (Beatles song) | Grafo: 1260 nós
# Camada 2 | Processando: Donatário | Grafo: 1262 nós
# Camada 2 | Processando: El Mercurio | Grafo: 1281 nós
# Camada 2 | Processando: Electric Warrior | Grafo: 1301 nós
# Camada 2 | Processando: Emma Stone | Grafo: 1310 nós
# Camada 2 | Processando: Enel (One Piece) | Grafo: 1323 nós
# Camada 2 | Processando: Equador, Rio Grande do Norte | Grafo: 1323 nós
# Camada 2 | Processando: Esports One | Grafo: 1327 nós
# Camada 2 | Processando: Espírito Santo, Rio Grande do Norte | Grafo: 1336 nós
# Camada 2 | Processando: Everyday (Ariana Grande song) | Grafo: 1337 nós
# Camada 2 | Processando: Everytime (Ariana Grande song) | Grafo: 1341 nós
# Camada 2 | Processando: Federazione Industria Musicale Italiana | Grafo: 1341 nós
# Camada 2 | Processando: Fifth Beatle | Grafo: 1359 nós
# Camada 2 | Processando: Film franchise | Grafo: 1362 nós
# Camada 2 | Processando: Four by the Beatles | Grafo: 1380 nós
# Camada 2 | Processando: Foxtel One | Grafo: 1380 nós
# Camada 2 | Processando: Foxy (One Piece) | Grafo: 1395 nós
# Camada 2 | Processando: France 2 | Grafo: 1395 nós
# Camada 2 | Processando: France 24 | Grafo: 1402 nós
# Camada 2 | Processando: France 3 | Grafo: 1411 nós
# Camada 2 | Processando: France 3 Alpes | Grafo: 1414 nós
# Camada 2 | Processando: France 3 Alsace | Grafo: 1414 nós
# Camada 2 | Processando: France 3 Aquitaine | Grafo: 1414 nós
# Camada 2 | Processando: France 3 Auvergne-Rhône-Alpes | Grafo: 1414 nós
# Camada 2 | Processando: France 3 Bourgogne | Grafo: 1414 nós
# Camada 2 | Processando: France 3 Bretagne | Grafo: 1414 nós
# Camada 2 | Processando: France 3 Centre | Grafo: 1414 nós
# Camada 2 | Processando: France Joli | Grafo: 1414 nós
# Camada 2 | Processando: France.tv | Grafo: 1429 nós
# Camada 2 | Processando: France.tv Slash | Grafo: 1432 nós
# Camada 2 | Processando: France.tv Sport | Grafo: 1437 nós
# Camada 2 | Processando: Francis Drake | Grafo: 1437 nós
# Camada 2 | Processando: Francisco de Sousa | Grafo: 1449 nós
# Camada 2 | Processando: Franco-Belgian comics | Grafo: 1449 nós
# Camada 2 | Processando: Galdino (One Piece) | Grafo: 1463 nós
# Camada 2 | Processando: GameRevolution | Grafo: 1463 nós
# Camada 2 | Processando: Ganbarion | Grafo: 1473 nós
# Camada 2 | Processando: Gin (One Piece) | Grafo: 1488 nós
# Camada 2 | Processando: Girl (Beatles song) | Grafo: 1488 nós
# Camada 2 | Processando: Global Beatles Day | Grafo: 1492 nós
# Camada 2 | Processando: God (The Beatles album) | Grafo: 1493 nós
# Camada 2 | Processando: Greatest Hits Volume 1 (Beatles album) | Grafo: 1497 nós
# Camada 2 | Processando: Greatest Hits Volume 2 (Beatles album) | Grafo: 1500 nós
# Camada 2 | Processando: HELP! A Beatles Tribute | Grafo: 1501 nós
# Camada 2 | Processando: Hear the Beatles Tell All | Grafo: 1501 nós
# Camada 2 | Processando: Hey Jude (Beatles album) | Grafo: 1501 nós
# Camada 2 | Processando: History of Rio Grande do Norte | Grafo: 1503 nós
# Camada 2 | Processando: Hit Me, Baby, One More Time (TV series) | Grafo: 1518 nós
# Camada 2 | Processando: Honey Don't | Grafo: 1536 nós
# Camada 2 | Processando: I Honestly Love You | Grafo: 1542 nós
# Camada 2 | Processando: I Left My Heart in San Francisco | Grafo: 1555 nós
# Camada 2 | Processando: In Their Lives: Great Writers on Great Beatles Songs | Grafo: 1575 nós
# Camada 2 | Processando: In the Zone | Grafo: 1578 nós
# Camada 2 | Processando: Introducing... The Beatles | Grafo: 1584 nós
# Camada 2 | Processando: Itajá, Rio Grande do Norte | Grafo: 1585 nós
# Camada 2 | Processando: Itaú, Rio Grande do Norte | Grafo: 1586 nós
# Camada 2 | Processando: Jandaíra, Rio Grande do Norte | Grafo: 1586 nós
# Camada 2 | Processando: Jango (One Piece) | Grafo: 1586 nós
# Camada 2 | Processando: Jaçanã, Rio Grande do Norte | Grafo: 1586 nós
# Camada 2 | Processando: José Francisco de Paula Cavalcanti de Albuquerque | Grafo: 1586 nós
# Camada 2 | Processando: Julia (Beatles song) | Grafo: 1586 nós
# Camada 2 | Processando: Jundiá, Rio Grande do Norte | Grafo: 1590 nós
# Camada 2 | Processando: Kuro (One Piece) | Grafo: 1590 nós
# Camada 2 | Processando: Kuroobi (One Piece) | Grafo: 1590 nós
# Camada 2 | Processando: Lajes, Rio Grande do Norte | Grafo: 1590 nós
# Camada 2 | Processando: Les Beatles dans leurs 14 plus grands succès | Grafo: 1595 nós
# Camada 2 | Processando: Literal translation | Grafo: 1595 nós
# Camada 2 | Processando: Live at the BBC (Beatles album) | Grafo: 1615 nós
# Camada 2 | Processando: Living the Beatles Legend | Grafo: 1617 nós
# Camada 2 | Processando: Los Beatles (album) | Grafo: 1617 nós
# Camada 2 | Processando: Love (Beatles album) | Grafo: 1617 nós
# Camada 2 | Processando: Love Songs (Beatles album) | Grafo: 1622 nós
# Camada 2 | Processando: Martin Scorsese Presents: Masterpieces of Polish Cinema | Grafo: 1625 nós
# Camada 2 | Processando: Martin Scorsese and Leonardo DiCaprio | Grafo: 1642 nós
# Camada 2 | Processando: Marylebone | Grafo: 1656 nós
# Camada 2 | Processando: Meet the Beatles! | Grafo: 1676 nós
# Camada 2 | Processando: Misery (Beatles song) | Grafo: 1676 nós
# Camada 2 | Processando: Mone-san no Majimesugiru Tsukiaikata | Grafo: 1678 nós
# Camada 2 | Processando: Money (That's What I Want) | Grafo: 1697 nós
# Camada 2 | Processando: Monte Alegre, Rio Grande do Norte | Grafo: 1703 nós
# Camada 2 | Processando: Morgan (One Piece) | Grafo: 1703 nós
# Camada 2 | Processando: Natal, Rio Grande do Norte | Grafo: 1703 nós
# Camada 2 | Processando: Norah Jones | Grafo: 1704 nós
# Camada 2 | Processando: Now and Then (Beatles song) | Grafo: 1716 nós
# Camada 2 | Processando: Nísia Floresta, Rio Grande do Norte | Grafo: 1719 nós
# Camada 2 | Processando: One After 909 | Grafo: 1720 nós
# Camada 2 | Processando: One Dance | Grafo: 1723 nós
# Camada 2 | Processando: One Direction | Grafo: 1728 nós
# Camada 2 | Processando: One Flew Over the Cuckoo's Nest (novel) | Grafo: 1742 nós
# Camada 2 | Processando: One Kiss (song) | Grafo: 1761 nós
# Camada 2 | Processando: One Piece: Gear Spirit | Grafo: 1770 nós
# Camada 2 | Processando: One Piece: Grand Battle! Rush | Grafo: 1779 nós
# Camada 2 | Processando: One Piece: Mamoru! Saigo no Dai Butai | Grafo: 1779 nós
# Camada 2 | Processando: One Piece: Pirate Warriors | Grafo: 1779 nós
# Camada 2 | Processando: One Piece: Pirate Warriors (video game) | Grafo: 1798 nós
# Camada 2 | Processando: One Piece: Pirate Warriors 2 | Grafo: 1798 nós
# Camada 2 | Processando: One Piece: Pirate Warriors 3 | Grafo: 1798 nós
# Camada 2 | Processando: One Piece: Pirate Warriors 4 | Grafo: 1798 nós
# Camada 2 | Processando: One Piece: Pirates' Carnival | Grafo: 1798 nós
# Camada 2 | Processando: One Taste of Honey | Grafo: 1798 nós
# Camada 2 | Processando: One Two Three Four: The Beatles in Time | Grafo: 1809 nós
# Camada 2 | Processando: One Way Records | Grafo: 1810 nós
# Camada 2 | Processando: One-hit wonder | Grafo: 1822 nós
# Camada 2 | Processando: Only The Beatles... | Grafo: 1842 nós
# Camada 2 | Processando: Outline of the Beatles | Grafo: 1845 nós
# Camada 2 | Processando: P.S. I Love You (Beatles song) | Grafo: 1849 nós
# Camada 2 | Processando: Parlophone | Grafo: 1849 nós
# Camada 2 | Processando: Passagem, Rio Grande do Norte | Grafo: 1863 nós
# Camada 2 | Processando: Pat Boone | Grafo: 1863 nós
# Camada 2 | Processando: Patu, Rio Grande do Norte | Grafo: 1877 nós
# Camada 2 | Processando: Pedra Preta, Rio Grande do Norte | Grafo: 1877 nós
# Camada 2 | Processando: Pernambucan revolt | Grafo: 1877 nós
# Camada 2 | Processando: Piece of Me | Grafo: 1891 nós
# Camada 2 | Processando: Planet Earth (franchise) | Grafo: 1898 nós
# Camada 2 | Processando: Pop Go the Beatles | Grafo: 1917 nós
# Camada 2 | Processando: Por Siempre Beatles | Grafo: 1917 nós
# Camada 2 | Processando: Problem (Ariana Grande song) | Grafo: 1918 nós
# Camada 2 | Processando: Rain (Beatles song) | Grafo: 1918 nós
# Camada 2 | Processando: Rain: A Tribute to the Beatles | Grafo: 1919 nós
# Camada 2 | Processando: Rarities (Beatles compilations) | Grafo: 1919 nós
# Camada 2 | Processando: Real Love (Beatles song) | Grafo: 1922 nós
# Camada 2 | Processando: Recording practices of the Beatles | Grafo: 1923 nós
# Camada 2 | Processando: Recording the Beatles | Grafo: 1927 nós
# Camada 2 | Processando: Religious views of the Beatles | Grafo: 1927 nós
# Camada 2 | Processando: Revolution (Beatles song) | Grafo: 1927 nós
# Camada 2 | Processando: Revolution in the Head: The Beatles' Records and the Sixties | Grafo: 1937 nós
# Camada 2 | Processando: Revolver (Beatles album) | Grafo: 1939 nós
# Camada 2 | Processando: Revolver: Special Edition | Grafo: 1944 nós
# Camada 2 | Processando: Riacho de Santana, Rio Grande do Norte | Grafo: 1944 nós
# Camada 2 | Processando: Riachuelo, Rio Grande do Norte | Grafo: 1944 nós
# Camada 2 | Processando: Rickie Lee Jones | Grafo: 1944 nós
# Camada 2 | Processando: Riot control | Grafo: 1958 nós
# Camada 2 | Processando: Rolling Stone | Grafo: 1978 nós
# Camada 2 | Processando: Rolling Stone's 100 Greatest Music Videos of All Time | Grafo: 1993 nós
# Camada 2 | Processando: Rolling Stone's 500 Greatest Songs of All Time | Grafo: 2010 nós
# Camada 2 | Processando: Roy Orbison/The Beatles Tour | Grafo: 2021 nós
# Camada 2 | Processando: Ruy Barbosa, Rio Grande do Norte | Grafo: 2025 nós
# Camada 2 | Processando: Santa Cruz, Rio Grande do Norte | Grafo: 2025 nós
# Camada 2 | Processando: Santo Antônio, Rio Grande do Norte | Grafo: 2026 nós
# Camada 2 | Processando: Sessions (Beatles album) | Grafo: 2027 nós
# Camada 2 | Processando: Sgt. Pepper's Lonely Hearts Club Band | Grafo: 2027 nós
# Camada 2 | Processando: Sgt. Pepper's Lonely Hearts Club Band (film) | Grafo: 2029 nós
# Camada 2 | Processando: Sgt. Pepper's Lonely Hearts Club Band (song) | Grafo: 2033 nós
# Camada 2 | Processando: Shout!: The Beatles in Their Generation | Grafo: 2034 nós
# Camada 2 | Processando: Someone You Loved | Grafo: 2035 nós
# Camada 2 | Processando: Something (Beatles song) | Grafo: 2040 nós
# Camada 2 | Processando: Standalone film | Grafo: 2050 nós
# Camada 2 | Processando: Stone Ocean | Grafo: 2069 nós
# Camada 2 | Processando: São Bento do Norte | Grafo: 2085 nós
# Camada 2 | Processando: São Miguel, Rio Grande do Norte | Grafo: 2085 nós
# Camada 2 | Processando: São Pedro, Rio Grande do Norte | Grafo: 2085 nós
# Camada 2 | Processando: São Rafael, Rio Grande do Norte | Grafo: 2085 nós
# Camada 2 | Processando: São Tomé, Rio Grande do Norte | Grafo: 2085 nós
# Camada 2 | Processando: Sítio Novo, Rio Grande do Norte | Grafo: 2085 nós
# Camada 2 | Processando: The Beatles (No. 1) | Grafo: 2085 nós
# Camada 2 | Processando: The Beatles (TV series) | Grafo: 2085 nós
# Camada 2 | Processando: The Beatles (album) | Grafo: 2086 nós
# Camada 2 | Processando: The Beatles (disambiguation) | Grafo: 2089 nós
# Camada 2 | Processando: The Beatles Anthology (TV series) | Grafo: 2089 nós
# Camada 2 | Processando: The Beatles Anthology (book) | Grafo: 2094 nós
# Camada 2 | Processando: The Beatles Experience | Grafo: 2094 nós
# Camada 2 | Processando: The Beatles Illustrated Lyrics | Grafo: 2109 nós
# Camada 2 | Processando: The Beatles Winter 1963 Helen Shapiro Tour | Grafo: 2110 nós
# Camada 2 | Processando: The Beatles albums discography | Grafo: 2110 nós
# Camada 2 | Processando: The Beatles and India | Grafo: 2110 nós
# Camada 2 | Processando: The Beatles singles discography | Grafo: 2111 nós
# Camada 2 | Processando: The Beatles' Christmas records | Grafo: 2111 nós
# Camada 2 | Processando: The Beatles' First | Grafo: 2111 nós
# Camada 2 | Processando: The Beatles' Movie Medley | Grafo: 2112 nós
# Camada 2 | Processando: The Beatles' North American releases | Grafo: 2115 nós
# Camada 2 | Processando: The Beatles: All These Years | Grafo: 2116 nós
# Camada 2 | Processando: The Beatles: An Illustrated Record | Grafo: 2116 nós
# Camada 2 | Processando: The Beatles: Eight Days a Week | Grafo: 2116 nós
# Camada 2 | Processando: The Beatles: Get Back | Grafo: 2121 nós
# Camada 2 | Processando: The Beatles: The Authorised Biography | Grafo: 2124 nós
# Camada 2 | Processando: The Beatles: The Biography | Grafo: 2124 nós
# Camada 2 | Processando: The Beatles: The First U.S. Visit | Grafo: 2125 nós
# Camada 2 | Processando: The Complete Beatles Recording Sessions | Grafo: 2126 nós
# Camada 2 | Processando: The Fifth Beatle (graphic novel) | Grafo: 2128 nós
# Camada 2 | Processando: Time zone | Grafo: 2130 nós
# Camada 2 | Processando: Tom Jones (singer) | Grafo: 2149 nós
# Camada 2 | Processando: Transfer of the Portuguese court to Brazil | Grafo: 2164 nós
# Camada 2 | Processando: Transmedia storytelling | Grafo: 2179 nós
# Camada 2 | Processando: Transmediation | Grafo: 2196 nós
# Camada 2 | Processando: What Goes On (Beatles song) | Grafo: 2211 nós
# Camada 2 | Processando: With the Beatles | Grafo: 2212 nós
# Camada 2 | Processando: You Never Give Me Your Money (book) | Grafo: 2212 nós
# Camada 2 | Processando: ...For Dummies | Grafo: 2216 nós
# Camada 2 | Processando: 1964: Eyes of the Storm | Grafo: 2234 nós
# Camada 2 | Processando: 1968 uprising | Grafo: 2239 nós
# Camada 2 | Processando: 2010 Brazilian census | Grafo: 2239 nós
# Camada 2 | Processando: 2022 Brazilian census | Grafo: 2253 nós
# Camada 2 | Processando: A Moment Like This | Grafo: 2258 nós
# Camada 2 | Processando: About Entertainment | Grafo: 2271 nós
# Camada 2 | Processando: Abstract comics | Grafo: 2291 nós
# Camada 2 | Processando: Academy of Comic Book Arts | Grafo: 2298 nós
# Camada 2 | Processando: Academy of Comic-Book Fans and Collectors | Grafo: 2315 nós
# Camada 2 | Processando: Adele | Grafo: 2329 nós
# Camada 2 | Processando: Adult comics | Grafo: 2332 nós
# Camada 2 | Processando: Adult contemporary | Grafo: 2346 nós
# Camada 2 | Processando: Afonso Bezerra | Grafo: 2359 nós
# Camada 2 | Processando: African characters in comics | Grafo: 2359 nós
# Camada 2 | Processando: Age group | Grafo: 2371 nós
# Camada 2 | Processando: Agency for Cultural Affairs | Grafo: 2389 nós
# Camada 2 | Processando: Agreste Potiguar (mesoregion) | Grafo: 2408 nós
# Camada 2 | Processando: Aires da Cunha | Grafo: 2409 nós
# Camada 2 | Processando: Akira Toriyama | Grafo: 2409 nós
# Camada 2 | Processando: Alessia Cara | Grafo: 2425 nós
# Camada 2 | Processando: Alexandre de Moura | Grafo: 2437 nós
# Camada 2 | Processando: Alicia Keys | Grafo: 2437 nós
# Camada 2 | Processando: AllMusic | Grafo: 2447 nós
# Camada 2 | Processando: AllMusic (identifier) | Grafo: 2462 nós
# Camada 2 | Processando: Alternative comics | Grafo: 2462 nós
# Camada 2 | Processando: Alto do Rodrigues | Grafo: 2475 nós
# Camada 2 | Processando: Ambiguous image | Grafo: 2475 nós
# Camada 2 | Processando: America (band) | Grafo: 2483 nós
# Camada 2 | Processando: American Idol | Grafo: 2493 nós
# Camada 2 | Processando: American comic book | Grafo: 2508 nós
# Camada 2 | Processando: Amusement park | Grafo: 2521 nós
# Camada 2 | Processando: Amy Winehouse | Grafo: 2540 nós
# Camada 2 | Processando: Animated series | Grafo: 2546 nós
# Camada 2 | Processando: Animated television series | Grafo: 2564 nós
# Camada 2 | Processando: Anime | Grafo: 2564 nós
# Camada 2 | Processando: Anime News Network | Grafo: 2576 nós
# Camada 2 | Processando: Anime's Media Mix | Grafo: 2594 nós
# Camada 2 | Processando: Anna Kyoyama | Grafo: 2611 nós
# Camada 2 | Processando: Annual publication | Grafo: 2627 nós
# Camada 2 | Processando: Another Taste | Grafo: 2642 nós
# Camada 2 | Processando: Antagonist | Grafo: 2649 nós
# Camada 2 | Processando: Anthology | Grafo: 2667 nós
# Camada 2 | Processando: Antihero | Grafo: 2685 nós
# Camada 2 | Processando: Argentine comics | Grafo: 2696 nós
# Camada 2 | Processando: Arm ring | Grafo: 2704 nós
# Camada 2 | Processando: Ashcan comic | Grafo: 2723 nós
# Camada 2 | Processando: Association of Canadian Cartoonists | Grafo: 2726 nós
# Camada 2 | Processando: Association of Comics Magazine Publishers | Grafo: 2744 nós
# Camada 2 | Processando: Astro Boy | Grafo: 2762 nós
# Camada 2 | Processando: Augusto Severo de Albuquerque Maranhão | Grafo: 2779 nós
# Camada 2 | Processando: Avalokiteśvara | Grafo: 2782 nós
# Camada 2 | Processando: Avengers Campus | Grafo: 2797 nós
# Camada 2 | Processando: Avex Group | Grafo: 2816 nós
# Camada 2 | Processando: Açu National Forest | Grafo: 2836 nós
# Camada 2 | Processando: Battlestar Galactica | Grafo: 2854 nós
# Camada 2 | Processando: Belém do Brejo do Cruz | Grafo: 2871 nós
# Camada 2 | Processando: Boa Saúde | Grafo: 2890 nós
# Camada 2 | Processando: Bob Iger | Grafo: 2893 nós
# Camada 2 | Processando: Bodhisattva | Grafo: 2910 nós
# Camada 2 | Processando: Bomber Girl | Grafo: 2919 nós
# Camada 2 | Processando: Book series | Grafo: 2929 nós
# Camada 2 | Processando: Borborema Potiguar | Grafo: 2943 nós
# Camada 2 | Processando: Brasília | Grafo: 2947 nós
# Camada 2 | Processando: Brazil | Grafo: 2960 nós
# Camada 2 | Processando: Brazilian Agricultural Research Corporation | Grafo: 2973 nós
# Camada 2 | Processando: Brazilian Institute of Geography and Statistics | Grafo: 2986 nós
# Camada 2 | Processando: Brazilian state | Grafo: 2997 nós
# Camada 2 | Processando: Broadcast media | Grafo: 2998 nós
# Camada 2 | Processando: Buddhahood | Grafo: 3014 nós
# Camada 2 | Processando: Buddhism | Grafo: 3018 nós
# Camada 2 | Processando: Busshi | Grafo: 3032 nós
# Camada 2 | Processando: Campo Redondo | Grafo: 3049 nós
# Camada 2 | Processando: Canon (fiction) | Grafo: 3049 nós
# Camada 2 | Processando: Cape Verde | Grafo: 3068 nós
# Camada 2 | Processando: Captain Tsubasa | Grafo: 3084 nós
# Camada 2 | Processando: Captaincies of Brazil | Grafo: 3099 nós
# Camada 2 | Processando: Captaincy of Ceará | Grafo: 3101 nós
# Camada 2 | Processando: Captaincy of Itamaracá | Grafo: 3115 nós
# Camada 2 | Processando: Captaincy of Maranhão | Grafo: 3123 nós
# Camada 2 | Processando: Captaincy of Paraíba | Grafo: 3125 nós
# Camada 2 | Processando: Captaincy of Pernambuco | Grafo: 3132 nós
# Camada 2 | Processando: Captaincy of São Vicente | Grafo: 3132 nós
# Camada 2 | Processando: Carnaubais | Grafo: 3146 nós
# Camada 2 | Processando: Catholicism | Grafo: 3148 nós
# Camada 2 | Processando: Ceará | Grafo: 3161 nós
# Camada 2 | Processando: Cowa! | Grafo: 3172 nós
# Camada 2 | Processando: Currais Novos | Grafo: 3179 nós
# Camada 2 | Processando: DNA² | Grafo: 3185 nós
# Camada 2 | Processando: Dharma | Grafo: 3201 nós
# Camada 2 | Processando: Diamond Is Unbreakable | Grafo: 3211 nós
# Camada 2 | Processando: Dirigible | Grafo: 3215 nós
# Camada 2 | Processando: Dog | Grafo: 3235 nós
# Camada 2 | Processando: Enlightenment in Buddhism | Grafo: 3253 nós
# Camada 2 | Processando: Felipe Guerra | Grafo: 3256 nós
# Camada 2 | Processando: Galinhos | Grafo: 3256 nós
# Camada 2 | Processando: Geographic coordinate system | Grafo: 3256 nós
# Camada 2 | Processando: Gini coefficient | Grafo: 3276 nós
# Camada 2 | Processando: Goianinha | Grafo: 3296 nós
# Camada 2 | Processando: Governador Dix-Sept Rosado | Grafo: 3296 nós
# Camada 2 | Processando: Grossos | Grafo: 3296 nós
# Camada 2 | Processando: Human Development Index | Grafo: 3297 nós
# Camada 2 | Processando: Intermediate and Immediate Geographic Regions | Grafo: 3314 nós
# Camada 2 | Processando: Janduís | Grafo: 3320 nós
# Camada 2 | Processando: Jardim de Angicos | Grafo: 3320 nós
# Camada 2 | Processando: Lagoa de Pedras | Grafo: 3320 nós
# Camada 2 | Processando: Lagoa de Velhos | Grafo: 3320 nós
# Camada 2 | Processando: Lajes Pintadas | Grafo: 3320 nós
# Camada 2 | Processando: Liberal Party (Brazil, 2006) | Grafo: 3320 nós
# Camada 2 | Processando: List of municipalities in Rio Grande do Norte | Grafo: 3336 nós
# Camada 2 | Processando: List of municipalities in Rio Grande do Norte (RN), Brazil | Grafo: 3337 nós
# Camada 2 | Processando: Luís Gomes | Grafo: 3337 nós
# Camada 2 | Processando: Macaíba | Grafo: 3339 nós
# Camada 2 | Processando: Mesoregion (Brazil) | Grafo: 3346 nós
# Camada 2 | Processando: Mesoregions of Brazil | Grafo: 3346 nós
# Camada 2 | Processando: Microregion (Brazil) | Grafo: 3346 nós
# Camada 2 | Processando: Microregions of Brazil | Grafo: 3346 nós
# Camada 2 | Processando: Mossoró | Grafo: 3346 nós
# Camada 2 | Processando: Municipalities of Brazil | Grafo: 3348 nós
# Camada 2 | Processando: Municipality (Brazil) | Grafo: 3360 nós
# Camada 2 | Processando: Northeast Region, Brazil | Grafo: 3360 nós
# Camada 2 | Processando: Population density | Grafo: 3366 nós
# Camada 2 | Processando: Regions of Brazil | Grafo: 3378 nós
# Camada 2 | Processando: States of Brazil | Grafo: 3383 nós
# Camada 2 | Processando: Time in Brazil | Grafo: 3383 nós
# Camada 2 | Processando: UTC-03:00 | Grafo: 3398 nós
# Camada 2 | Processando: List of cities in Brazil | Grafo: 3408 nós
# Camada 2 | Processando: List of sovereign states | Grafo: 3419 nós
# ------------------------------
# COLETA FINALIZADA!
# Total: 3434 nós e 8956 arestas.

# %% [markdown]
# - Tratamento de Dados (Limpeza)
#   Remoção de duplicatas (ex: plurais) e auto-loops, conforme feito no notebook do professor.

# %%
print(f"Iniciando limpeza em grafo de {len(g)} nós...")
print("Isso pode demorar um pouco devido ao tamanho da rede.")

# 1. Remover auto-loops (Rápido e seguro)
g.remove_edges_from(nx.selfloop_edges(g))

# 2. Fundir plurais (Ex: 'Palavra' e 'Palavras') com verificação
duplicates = [(node, node + "s") for node in g if node + "s" in g]
for u, v in duplicates:
    if u in g and v in g: # <--- PROTEÇÃO: Só funde se ambos ainda existirem
        g = nx.contracted_nodes(g, u, v, self_loops=False)

# 3. Fundir hífens (Ex: 'One-Punch Man' e 'One Punch Man') com verificação
duplicates_hyphen = [(node, node.replace("-", " ")) for node in g
                     if node.replace("-", " ") in g and node != node.replace("-", " ")]

for u, v in duplicates_hyphen:
    if u in g and v in g: # <--- PROTEÇÃO: Só funde se ambos ainda existirem
        g = nx.contracted_nodes(g, u, v, self_loops=False)

# Limpeza técnica de atributos (para evitar erros no Gephi)
for node in g.nodes():
    g.nodes[node].pop('contraction', None)
for u, v in g.edges():
    g.edges[u, v].pop('contraction', None)

print(f"Limpeza concluída! Grafo atual: {len(g)} nós.")
# Out:
# Iniciando limpeza em grafo de 3425 nós...
# Isso pode demorar um pouco devido ao tamanho da rede.
# Limpeza concluída! Grafo atual: 3425 nós.

# %% [markdown]
# - Filtragem e Exportação
#
#   Gera o arquivo final .graphml.

# %%
# Filtra o "Core" da rede: Mantém apenas nós com grau >= 2
# (Nós que têm pelo menos 2 conexões de entrada ou saída)
core = [node for node, deg in dict(g.degree()).items() if deg >= 2]
gsub = g.subgraph(core).copy()

print("-" * 30)
print(f"Grafo Original: {len(g)} nós")
print(f"Grafo Final (Core): {len(gsub)} nós")
print("-" * 30)

# Salva o arquivo para o Gephi
nome_arquivo = "trabalho_final_validacao.graphml"
nx.write_graphml(gsub, nome_arquivo)

print(f"Arquivo '{nome_arquivo}' salvo com sucesso!")
print("Faça o download na aba de arquivos (ícone da pasta) à esquerda.")
# Out:
# ------------------------------
# Grafo Original: 3425 nós
# Grafo Final (Core): 978 nós
# ------------------------------
# Arquivo 'trabalho_final_validacao.graphml' salvo com sucesso!
# Faça o download na aba de arquivos (ícone da pasta) à esquerda.
